# %% [markdown]
# # NWB widget example
#
# Working with this code:
#
# Open up a terminal and enter the following
#
#         conda create -n env python=3.9
#         conda activate env
#         pip install numpy scipy matplotlib pandas ipykernel pynwb nwbwidgets jupyterlab
#
# Restart terminal and enter the following:
#
#         conda activate env
#         jupyter lab
#
# When jupyter-lab fires up:
# 1) Press on "Python 3 (ipykernel)" and hit the "select" button before running any of these lines
#
# Just hit shift+enter to run a cell
#
# ---

# %% [markdown]
# ####  Import some packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from pynwb import NWBHDF5IO, NWBFile

# %% [markdown]
# #### A helper function to read NWB files

# %%
# some general helper functions for nwb stuff
def read_nwb(pathname: str):
    """
        Read NWB files
        Args:
            >>> nwbpath: path directly to the nwb file pathname="Users/.../nwbfile.nwb"
    """
    io = NWBHDF5IO(pathname, mode="r")
    nwb_file = io.read()

    return nwb_file

# %% [markdown]
# #### Load in data and visualize
#
# * Change `filepath` to wherever you downloaded the nwbfile

# %%
# change me
filepath = '/Users/js0403/local data/2020-06-26_16-56-10 9&10eb male ACTH ELS/nwbfile.nwb'
nwbfile = read_nwb(filepath)

# %% [markdown]
# ### NWBwidgets
#
# Press on the 'acquisition' drop down menu and you can explore the LFP data (try the group inputs in the drop down menu)
#
# Also, you can press on the 'units' menu and see example rasters. Not everything works here yet

# %%
from nwbwidgets import nwb2widget
nwb2widget(nwbfile)
# Out:
# VBox(children=(HBox(children=(Label(value='session_description:', layout=Layout(max_height='40px', max_width='…
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:655, in Widget.set_state(self, sync_data)
#     652 if name in self.keys:
#     653     from_json = self.trait_metadata(name, 'from_json',
#     654                                     self._trait_from_json)
# --> 655     self.set_trait(name, from_json(sync_data[name], self))
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/contextlib.py:126, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     124 if typ is None:
#     125     try:
# --> 126         next(self.gen)
#     127     except StopIteration:
#     128         return False
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1529, in HasTraits.hold_trait_notifications(self)
#    1527 for changes in cache.values():
#    1528     for change in changes:
# -> 1529         self.notify_change(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1544, in HasTraits.notify_change(self, change)
#    1542 def notify_change(self, change):
#    1543     """Notify observers of a change event"""
# -> 1544     return self._notify_observers(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1591, in HasTraits._notify_observers(self, event)
#    1588 elif isinstance(c, EventHandler) and c.name is not None:
#    1589     c = getattr(self, c.name)
# -> 1591 c(event)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/base.py:130, in lazy_tabs.<locals>.on_selected_index(change)
#     128 def on_selected_index(change):
#     129     if isinstance(change.owner.children[change.new], widgets.HTML):
# --> 130         children[change.new] = vis2widget(tabs_spec[change.new][1](node))
#     131         change.owner.children = children
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/misc.py:1135, in RasterGridWidget.__init__(self, units, trials, unit_index, units_trials_controller)
#    1131     units_trials_controller = UnitsAndTrialsControllerWidget(units=units, trials=trials, unit_index=unit_index)
#    1132     self.children = [units_trials_controller]
#    1134 self.fig = interactive_output(
# -> 1135     f=raster_grid, controls=units_trials_controller.controls, fixed=units_trials_controller.fixed
#    1136 )
#    1138 self.children += tuple([self.fig])
#
# AttributeError: 'UnitsAndTrialsControllerWidget' object has no attribute 'controls'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:655, in Widget.set_state(self, sync_data)
#     652 if name in self.keys:
#     653     from_json = self.trait_metadata(name, 'from_json',
#     654                                     self._trait_from_json)
# --> 655     self.set_trait(name, from_json(sync_data[name], self))
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/contextlib.py:126, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     124 if typ is None:
#     125     try:
# --> 126         next(self.gen)
#     127     except StopIteration:
#     128         return False
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1529, in HasTraits.hold_trait_notifications(self)
#    1527 for changes in cache.values():
#    1528     for change in changes:
# -> 1529         self.notify_change(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1544, in HasTraits.notify_change(self, change)
#    1542 def notify_change(self, change):
#    1543     """Notify observers of a change event"""
# -> 1544     return self._notify_observers(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1591, in HasTraits._notify_observers(self, event)
#    1588 elif isinstance(c, EventHandler) and c.name is not None:
#    1589     c = getattr(self, c.name)
# -> 1591 c(event)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/base.py:130, in lazy_tabs.<locals>.on_selected_index(change)
#     128 def on_selected_index(change):
#     129     if isinstance(change.owner.children[change.new], widgets.HTML):
# --> 130         children[change.new] = vis2widget(tabs_spec[change.new][1](node))
#     131         change.owner.children = children
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/misc.py:1158, in TuningCurveWidget.__init__(self, units, trials, unit_index, units_trials_controller)
#    1154     units_trials_controller = UnitsAndTrialsControllerWidget(units=units, trials=trials, unit_index=unit_index)
#    1155     self.children = [units_trials_controller]
#    1157 self.fig = interactive_output(
# -> 1158     f=draw_tuning_curve, controls=units_trials_controller.controls, fixed=units_trials_controller.fixed
#    1159 )
#    1161 self.children += tuple([self.fig])
#
# AttributeError: 'UnitsAndTrialsControllerWidget' object has no attribute 'controls'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:655, in Widget.set_state(self, sync_data)
#     652 if name in self.keys:
#     653     from_json = self.trait_metadata(name, 'from_json',
#     654                                     self._trait_from_json)
# --> 655     self.set_trait(name, from_json(sync_data[name], self))
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/contextlib.py:126, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     124 if typ is None:
#     125     try:
# --> 126         next(self.gen)
#     127     except StopIteration:
#     128         return False
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1529, in HasTraits.hold_trait_notifications(self)
#    1527 for changes in cache.values():
#    1528     for change in changes:
# -> 1529         self.notify_change(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1544, in HasTraits.notify_change(self, change)
#    1542 def notify_change(self, change):
#    1543     """Notify observers of a change event"""
# -> 1544     return self._notify_observers(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1591, in HasTraits._notify_observers(self, event)
#    1588 elif isinstance(c, EventHandler) and c.name is not None:
#    1589     c = getattr(self, c.name)
# -> 1591 c(event)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/base.py:130, in lazy_tabs.<locals>.on_selected_index(change)
#     128 def on_selected_index(change):
#     129     if isinstance(change.owner.children[change.new], widgets.HTML):
# --> 130         children[change.new] = vis2widget(tabs_spec[change.new][1](node))
#     131         change.owner.children = children
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/misc.py:1172, in TuningCurveExtendedWidget.__init__(self, units, trials, unit_index)
#    1169 self.units_trials_controller = UnitsAndTrialsControllerWidget(units=units, trials=trials, unit_index=unit_index)
#    1171 # Tuning curve widget
# -> 1172 self.tuning_curve = TuningCurveWidget(
#    1173     units=units,
#    1174     trials=trials,
#    1175     unit_index=unit_index,
#    1176     units_trials_controller=self.units_trials_controller,
#    1177 )
#    1179 # Raster grid widget
#    1180 self.raster_grid = RasterGridWidget(
#    1181     units=units,
#    1182     trials=trials,
#    1183     unit_index=unit_index,
#    1184     units_trials_controller=self.units_trials_controller,
#    1185 )
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/misc.py:1158, in TuningCurveWidget.__init__(self, units, trials, unit_index, units_trials_controller)
#    1154     units_trials_controller = UnitsAndTrialsControllerWidget(units=units, trials=trials, unit_index=unit_index)
#    1155     self.children = [units_trials_controller]
#    1157 self.fig = interactive_output(
# -> 1158     f=draw_tuning_curve, controls=units_trials_controller.controls, fixed=units_trials_controller.fixed
#    1159 )
#    1161 self.children += tuple([self.fig])
#
# AttributeError: 'UnitsAndTrialsControllerWidget' object has no attribute 'controls'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:655, in Widget.set_state(self, sync_data)
#     652 if name in self.keys:
#     653     from_json = self.trait_metadata(name, 'from_json',
#     654                                     self._trait_from_json)
# --> 655     self.set_trait(name, from_json(sync_data[name], self))
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/contextlib.py:126, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     124 if typ is None:
#     125     try:
# --> 126         next(self.gen)
#     127     except StopIteration:
#     128         return False
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1529, in HasTraits.hold_trait_notifications(self)
#    1527 for changes in cache.values():
#    1528     for change in changes:
# -> 1529         self.notify_change(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1544, in HasTraits.notify_change(self, change)
#    1542 def notify_change(self, change):
#    1543     """Notify observers of a change event"""
# -> 1544     return self._notify_observers(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1591, in HasTraits._notify_observers(self, event)
#    1588 elif isinstance(c, EventHandler) and c.name is not None:
#    1589     c = getattr(self, c.name)
# -> 1591 c(event)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/base.py:130, in lazy_tabs.<locals>.on_selected_index(change)
#     128 def on_selected_index(change):
#     129     if isinstance(change.owner.children[change.new], widgets.HTML):
# --> 130         children[change.new] = vis2widget(tabs_spec[change.new][1](node))
#     131         change.owner.children = children
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/misc.py:1158, in TuningCurveWidget.__init__(self, units, trials, unit_index, units_trials_controller)
#    1154     units_trials_controller = UnitsAndTrialsControllerWidget(units=units, trials=trials, unit_index=unit_index)
#    1155     self.children = [units_trials_controller]
#    1157 self.fig = interactive_output(
# -> 1158     f=draw_tuning_curve, controls=units_trials_controller.controls, fixed=units_trials_controller.fixed
#    1159 )
#    1161 self.children += tuple([self.fig])
#
# AttributeError: 'UnitsAndTrialsControllerWidget' object has no attribute 'controls'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:655, in Widget.set_state(self, sync_data)
#     652 if name in self.keys:
#     653     from_json = self.trait_metadata(name, 'from_json',
#     654                                     self._trait_from_json)
# --> 655     self.set_trait(name, from_json(sync_data[name], self))
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/contextlib.py:126, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     124 if typ is None:
#     125     try:
# --> 126         next(self.gen)
#     127     except StopIteration:
#     128         return False
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1529, in HasTraits.hold_trait_notifications(self)
#    1527 for changes in cache.values():
#    1528     for change in changes:
# -> 1529         self.notify_change(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1544, in HasTraits.notify_change(self, change)
#    1542 def notify_change(self, change):
#    1543     """Notify observers of a change event"""
# -> 1544     return self._notify_observers(change)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/traitlets/traitlets.py:1591, in HasTraits._notify_observers(self, event)
#    1588 elif isinstance(c, EventHandler) and c.name is not None:
#    1589     c = getattr(self, c.name)
# -> 1591 c(event)
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/base.py:130, in lazy_tabs.<locals>.on_selected_index(change)
#     128 def on_selected_index(change):
#     129     if isinstance(change.owner.children[change.new], widgets.HTML):
# --> 130         children[change.new] = vis2widget(tabs_spec[change.new][1](node))
#     131         change.owner.children = children
#
# File ~/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/nwbwidgets/misc.py:1158, in TuningCurveWidget.__init__(self, units, trials, unit_index, units_trials_controller)
#    1154     units_trials_controller = UnitsAndTrialsControllerWidget(units=units, trials=trials, unit_index=unit_index)
#    1155     self.children = [units_trials_controller]
#    1157 self.fig = interactive_output(
# -> 1158     f=draw_tuning_curve, controls=units_trials_controller.controls, fixed=units_trials_controller.fixed
#    1159 )
#    1161 self.children += tuple([self.fig])
#
# AttributeError: 'UnitsAndTrialsControllerWidget' object has no attribute 'controls'

# %% [markdown]
# ## Accessing components of NWB to plot

# %%
# numpy array of LFP data
LFP_data = nwbfile.acquisition['ElectricalSeries'].data[:]

# define sampling rate
fs = 32000

print("Signal on Y, Wire on X", LFP_data.shape)
# Out:
# Signal on Y, Wire on X (40848770, 16)

# %%
# example figure
plt.plot(LFP_data[0:fs,0], color = 'r', linewidth = 0.5)
plt.title("1s of LFP from channel 0 (channel 1)")
plt.xlabel("Samples")
plt.ylabel("Voltage")
# Out:
# Text(0, 0.5, 'Voltage')

# %% [markdown]
# ## Here is an example function that I made for visualizing. Quite like the NWB file tool

# %%
# lets inherit the __init__ from process_signal
def lfp_plotter(csc_data, fs, time_range: list = [0, 1], color = None):

    """
    Generate plotting function that plots as many rows as there are signals

    Args:
        >>> csc_data: numpy array of LFP data (samples on rows, wire on cols)
        >>> time_range: list telling the figure what to plot. Default is the first second.
        >>> fs: sampling rate of data

    Optional Args:
        >>> color: default is a single value, 'k'. This can take as many colors as there are data points.

    """
    # get shape of csc_data
    csc_shape = csc_data.shape
    if csc_shape[0] < csc_shape[1]:
        KeyError("Invert your csc_data shape. Make sure samples is on the row dimension")

    # get csc_data
    if color is None:
        temp_color = 'k'
        color = [temp_color[0] for i in range(csc_shape[1])]

    # get sampling rate - this method and class will be inherited by ioreaders
    fig, axes = plt.subplots(nrows=csc_shape[1],ncols=1,)
    idx = [int(time_range[0]*fs),int(time_range[1]*fs)]
    x_data = np.linspace(time_range[0],time_range[1],int(fs*(time_range[1]-time_range[0])))
    for i in range(csc_shape[1]):
        if len(axes) > 1:
            if i == csc_shape[1]-1:
                axes[i].plot(x_data, csc_data[idx[0]:idx[1],i],color[i],linewidth=0.5)
                axes[i].set_xlabel("Time (sec)")
            else:
                axes[i].plot(x_data, csc_data[idx[0]:idx[1],i],color[i],linewidth=0.5)
                #axes[i].xlabel("Time (sec)")
            axes[i].yaxis.set_tick_params(labelsize=8)
            axes[i].xaxis.set_tick_params(labelsize=8)
        else:
            axes.plot(x_data, csc_data[idx[0]:idx[1],i],color[i],linewidth=0.5)
            axes.set_xlabel("Time (sec)")  
            axes.yaxis.set_tick_params(labelsize=8)
            axes.xaxis.set_tick_params(labelsize=8)                              
        #var(axes[i])
    fig.show()

# %%
# Using the tool. Just change time_range to whatever you want
time_range = [100, 101] # in seconds
colors = None
colors = ['k','k','k','k','b','b','b','b','r','r','r','r','m','m','m','m']
lfp_plotter(csc_data = LFP_data, fs = fs, time_range = time_range, color = colors)
# Out:
# /var/folders/f3/11w5x6bs32gd1xc4lh41qdnr0000gp/T/ipykernel_36128/3526212499.py:46: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
