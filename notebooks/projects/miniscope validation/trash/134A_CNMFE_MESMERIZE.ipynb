# %% [markdown]
# # CNMF-E demo pipeline: Intro
# This notebook demonstrates how to use Caiman for processing 1p microendoscopic data. It shows how to use Caiman for the following steps:
#
# ![cnmfe pipeline full](https://raw.githubusercontent.com/EricThomson/image_sandbox/main/images/full_cnmfe_workflow.jpg)
#
# 1. Apply the NoRMCorre (nonrigid motion correction) algorithm for motion correction.
# 2. Apply the constrained nonnegative matrix factorization endoscopic (CNMF-E) source separation algorithm to extract an initial estimate of neuronal spatial footprint and calcium traces.
# 3. Apply quality control metrics to evaluate the initial estimates, and narrow down to the final set of estimates.
#
# Some tools for visualization of movies and results are also included.
#
# > This demo follows a similar pattern to the CNMF demo in `demo_pipeline.ipynb`. It includes less explanation except where there are important differences. If you want to get a more explanation-heavy picture of the fundamentals, we suggest starting with `demo_pipeline.ipynb`.

# %% [markdown]
# # Imports and general setup

# %%
import bokeh.plotting as bpl
import cv2
import glob
import holoviews as hv
from IPython import get_ipython
import logging
import matplotlib.pyplot as plt
import numpy as np
import os
import psutil

import caiman as cm
from caiman.source_extraction import cnmf
from caiman.source_extraction.cnmf.cnmf import load_CNMF
from caiman.utils.utils import download_demo
from caiman.utils.visualization import inspect_correlation_pnr, nb_inspect_correlation_pnr
from caiman.motion_correction import MotionCorrect
from caiman.source_extraction.cnmf import params as params
from caiman.utils.visualization import plot_contours, nb_view_patches, nb_plot_contour
from caiman.utils.visualization import view_quilt

try:
    if __IPYTHON__:
        get_ipython().run_line_magic('load_ext', 'autoreload')
        get_ipython().run_line_magic('autoreload', '2')
        # get_ipython().run_line_magic('matplotlib', 'qt')  #uncomment to run in qt mode
except NameError:
    pass

try:
    cv2.setNumThreads(0)
except:
    pass

bpl.output_notebook()
hv.notebook_extension('bokeh')

# Mesmerize inputs
from copy import deepcopy
import pandas as pd
import tifffile
from ipywidgets import IntSlider, VBox
import fastplotlib as fpl

from caiman.motion_correction import high_pass_filter_space
from caiman.summary_images import correlation_pnr

import mesmerize_core as mc
import caiman as cm
from mesmerize_core.arrays import LazyTiff
from mesmerize_viz import *
from decode_lab_code.utils import calcium_imaging_utils

from mesmerize_core.caiman_extensions.cnmf import cnmf_cache
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="da148805-ae9b-4700-bd0a-d72cbb9039f0">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="fd603a4b-d722-4304-81c0-4042c59d2c0e" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"3fed977d-1828-45fa-bc7e-a12fa366ee77":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"21a8894adace4b67adc6ddd4835273c6","client_comm_id":"487d402892514aa5bd11f6f74b0734e4"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"3fed977d-1828-45fa-bc7e-a12fa366ee77","roots":{"p1002":"fd603a4b-d722-4304-81c0-4042c59d2c0e"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cd218836-2d64-4e60-b5f0-4634f9768f74">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# Set up logger and environment variables

# %%
# set up logging
logging.basicConfig(format="{asctime} - {levelname} - [{filename} {funcName}() {lineno}] - pid {process} - {message}",
                    filename=None, 
                    level=logging.WARNING, style="{") #logging level can be DEBUG, INFO, WARNING, ERROR, CRITICAL

# set env variables in case they weren't already set
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["VECLIB_MAXIMUM_THREADS"] = "1"

# %% [markdown]
# # Select file(s) to be processed
# Here, we analyze the data in `data_endoscope.tif`. The `download_demo` function will download the  file for you and return the complete path to the file which will be stored in your `caiman_data` directory. If you adapt this demo for your data make sure to pass the complete path to your file.
#
# Note that the memory requirement of the CNMF-E algorithm are much higher compared to the standard CNMF algorithm. You should test your system before trying to process very large amounts of data.

# %%
#movie_path = download_demo('data_endoscope.tif')  

# directory stuff
folder_name = "/Users/js0403/miniscope/data/134A/AAV2/3-Syn-GCaMP8f/2023_11_14/13_19_36/miniscopeDeviceName/"
file_name = "0.avi"
frame_rate = 20 # frames per sec
mc.set_parent_raw_data_path(folder_name)

# split frames and save data
fname = [os.path.join(folder_name,file_name)]

# get the actual file name
movie_path  = mc.get_parent_raw_data_path().joinpath(file_name) # add to moviepath

# batch stuff - don't worry about
batch_path = mc.get_parent_raw_data_path().joinpath("mesmerize-batch/batch.pickle")
try:
    # create a new batch
    df = mc.create_batch(batch_path)
    print("Created batch")
except:
    # to load existing batches use `load_batch()`
    df = mc.load_batch(batch_path)
    print("Loaded batch")
# Out:
# Loaded batch

# %% [markdown]
# # Load and visualize raw data
# We visualize using the built-in movie object, which is described in detail in `demo_pipeline.ipynb`. In addition to neural activity, you can also see blood flow in the movie.

# %%
# press q to close
movie_orig = cm.load(str(movie_path)) 
downsampling_ratio = 0.2  # subsample 5x
movie_orig.resize(fz=downsampling_ratio).play(gain=0.9,
                                              q_max=99.5, 
                                              fr=frame_rate,
                                              plot_text=True,
                                              magnification=2,
                                              do_loop=True,
                                              backend='opencv')

# %% [markdown]
# # Set up a cluster
# To enable parallel computing we will set up a local cluster. The resulting variable `cluster` contains the pool of processors (CPUs) that will be used in later steps. If you use `dview=cluster` in later steps, then parallel processing will be used. If you use `dview=None` then no parallel processing will be used. The `num_processors_to_use` variable determines how many CPU dores you will use (when set to `None` it goes to the default of one less than the number available):

# %%
print(f"You have {psutil.cpu_count()} CPUs available in your current environment")
num_processors_to_use = 11
# Out:
# You have 12 CPUs available in your current environment

# %% [markdown]
# Set up a cluster of processors. If one has already been set up (the multiprocessing_pool variable is already in your namespace), then that cluster will be closed and a new one created.

# %%
#%% start a cluster for parallel processing (if a cluster already exists it will be closed and a new session will be opened)
if 'cluster' in locals():  # 'locals' contains list of current local variables
    print('Closing previous cluster')
    cm.stop_server(dview=cluster)
print("Setting up new cluster")
_, cluster, n_processes = cm.cluster.setup_cluster(backend='multiprocessing', 
                                                 n_processes=num_processors_to_use, 
                                                 ignore_preexisting=False)
print(f"Successfully set up cluster with {n_processes} processes")
# Out:
# Setting up new cluster
# Successfully set up cluster with 11 processes

# %% [markdown]
# # Visualize data to define parameter space

# %%
stride = 100; overlap = 50; width = stride+overlap; rf = int(width/2)
calcium_imaging_utils.view_quilt(template_image=np.mean(movie_orig,axis=0),stride=stride,overlap=overlap)
# Out:
# <Axes: >

# %%
# create a slider for gSig_filt
slider_gsig_filt = IntSlider(value=3, min=1, max=33, step=2,  description="gSig_filt")

def apply_filter(frame):
    # read slider value
    gSig_filt = (slider_gsig_filt.value, slider_gsig_filt.value)
    
    # apply filter
    return high_pass_filter_space(frame, gSig_filt)

# we can use frame_apply feature of `ImageWidget` to apply 
# the filter before displaying frames
funcs = {
    # data_index: function
    1: apply_filter  # filter shown on right plot, index 1
}

# input movie will be shown on left, filtered on right
iw_gs = fpl.ImageWidget(
    data=[movie_orig, movie_orig.copy()],
    frame_apply=funcs,
    names=["raw", "filtered"],
    grid_plot_kwargs={"size": (1200, 600)},
    cmap="gnuplot2"
)

def force_update(*args):
    # kinda hacky but forces the images to update 
    # when the gSig_filt slider is moved
    iw_gs.current_index = iw_gs.current_index
    iw_gs.reset_vmin_vmax()

iw_gs.reset_vmin_vmax()
slider_gsig_filt.observe(force_update, "value")
VBox([iw_gs.show(), slider_gsig_filt])
# Out:
# RFBOutputContext()
# /Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/fastplotlib/graphics/_features/_base.py:34: UserWarning: converting float64 array to float32
#   warn(f"converting {array.dtype} array to float32")
# VBox(children=(JupyterOutputContext(children=(JupyterWgpuCanvas(css_height='600px', css_width='1200px'), Ipywi…

# %% [markdown]
# # Set up some parameters
# We first set some parameters related to the data and motion correction and create a `params` object. We'll modify this parameter object later on with settings for source extraction. You can also set all the parameters at once as demonstrated in the `demo_pipeline.ipynb` notebook.
#
# Note here we are setting `pw_rigid` to `False` as our data seems to mainly contain large-scale translational motion. We can always redo this later if it turns out to be a mistake.

# %%
gSig_val = 13 # update based on results from above

# dataset dependent parameters
frate = frame_rate                     # movie frame rate
decay_time = 0.4                 # length of a typical transient in seconds

# motion correction parameters
motion_correct = True    # flag for performing motion correction
pw_rigid = False         # flag for performing piecewise-rigid motion correction (otherwise just rigid)
gSig_filt = (gSig_val, gSig_val)       # size of high pass spatial filtering, used in 1p data
max_shifts = (5, 5)      # maximum allowed rigid shift
strides = (stride, stride)       # start a new patch for pw-rigid motion correction every x pixels
overlaps = (overlap, overlap)      # overlap between pathes (size of patch strides+overlaps)
max_deviation_rigid = 3  # maximum deviation allowed for patch with respect to rigid shifts
border_nan = 'copy'      # replicate values along the boundaries

mc_dict = {
    'fnames': str(movie_path),
    'fr': frate,
    'decay_time': decay_time,
    'pw_rigid': pw_rigid,
    'max_shifts': max_shifts,
    'gSig_filt': gSig_filt,
    'strides': strides,
    'overlaps': overlaps,
    'max_deviation_rigid': max_deviation_rigid,
    'border_nan': border_nan
}

parameters = params.CNMFParams(params_dict=mc_dict)

# %% [markdown]
# # Motion Correction
# The background signal in micro-endoscopic data is very strong and makes motion correction challenging. As a first step the algorithm performs a high pass spatial filtering with a Gaussian kernel to remove the bulk of the lower-frequency background activity and enhance spatial landmarks. The size of the kernel is given from the parameter `gSig_filt`. If this is left to the default value of `None` then no spatial filtering is performed (default option, used in 2p data for CNMF).
#
# After spatial filtering, the NoRMCorre algorithm is used to determine the motion in each frame. The inferred motion is then applied to the *original* data, so no information is lost before source separation. The motion corrected files are saved in memory mapped format. If no motion correction is performed (i.e., `motion_correct` was set to `False`), then the file gets directly memory mapped.
#
# > For a more detailed exploration of Caiman's motion correction pipeline, see `demo_motion_correction.ipynb`.
#
# The following also plots the discovered displacements in x- and y- in the movie.

# %%
# %%time
if motion_correct:
    # do motion correction rigid
    mot_correct = MotionCorrect(str(movie_path), dview=cluster, **parameters.get_group('motion'))
    mot_correct.motion_correct(save_movie=True)
    fname_mc = mot_correct.fname_tot_els if pw_rigid else mot_correct.fname_tot_rig
    if pw_rigid:
        bord_px = np.ceil(np.maximum(np.max(np.abs(mot_correct.x_shifts_els)),
                                     np.max(np.abs(mot_correct.y_shifts_els)))).astype(int)
    else:
        bord_px = np.ceil(np.max(np.abs(mot_correct.shifts_rig))).astype(int)
        # Plot shifts
        plt.plot(mot_correct.shifts_rig)  # % plot rigid shifts
        plt.legend(['x shifts', 'y shifts'])
        plt.xlabel('frames')
        plt.ylabel('pixels')
        plt.gcf().set_size_inches(6,3)
        plt.axhline(y=max_deviation_rigid, color='r', linestyle='-')
        plt.axhline(y=-1*max_deviation_rigid, color='r', linestyle='-')
        plt.title("Make sure that your max shifts dont exceed or peak at the red lines")
        

    bord_px = 0 if border_nan == 'copy' else bord_px
    fname_new = cm.save_memmap(fname_mc, base_name='memmap_', order='C',
                               border_to_0=bord_px)
else:  # if no motion correction just memory map the file
    fname_new = cm.save_memmap(movie_path, base_name='memmap_',
                               order='C', border_to_0=0, dview=dview)
# Out:
# 2023-11-15 11:41:24,924 - WARNING - [movies.py extract_shifts() 341] - pid 42983 - Movie average is negative. Removing 1st percentile.
# 2023-11-15 11:41:24,937 - WARNING - [movies.py extract_shifts() 359] - pid 42983 - Movie average is negative. Removing 1st percentile.
# 2023-11-15 11:41:25,629 - WARNING - [movies.py extract_shifts() 341] - pid 42983 - Movie average is negative. Removing 1st percentile.
# 2023-11-15 11:41:25,640 - WARNING - [movies.py extract_shifts() 359] - pid 42983 - Movie average is negative. Removing 1st percentile.
# 2023-11-15 11:41:26,312 - WARNING - [movies.py extract_shifts() 341] - pid 42983 - Movie average is negative. Removing 1st percentile.
# 2023-11-15 11:41:26,322 - WARNING - [movies.py extract_shifts() 359] - pid 42983 - Movie average is negative. Removing 1st percentile.
# CPU times: user 14.6 s, sys: 1.88 s, total: 16.5 s
# Wall time: 24 s

# %% [markdown]
# Compare original (left) and motion corrected movie (right).
#
# You will probably notice they look pretty similar, as there wasn't much motion to begin with. You can see from the shift plot (plotted above) that the extracted shifts were all very small.

# %%
movie_corrected = cm.load(mot_correct.mmap_file) # load motion corrected movie
ds_ratio = 0.2
cm.concatenate([movie_orig.resize(1, 1, ds_ratio) - mot_correct.min_mov*mot_correct.nonneg_movie,
                movie_corrected.resize(1, 1, ds_ratio)], 
                axis=2).play(fr=20, 
                             gain=0.9, 
                             magnification=2)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.02it/s]

# %% [markdown]
# ## Load memory mapped file
# Memory mapping is discussed in some detail in `demo_pipeline.ipynb`.

# %%
# load memory mappable file
Yr, dims, T = cm.load_memmap(fname_new)
images = Yr.T.reshape((T,) + dims, order='F')

# %% [markdown]
# # CNMFE requires a good pnr and corr input, so lets visualize to define them

# %%
gSig = gSig_val
corr, pnr = correlation_pnr(images[::2], gSig=gSig, swap_dim=False)

# %%
# to show the correlation and pnr images
iw_corr_pnr = fpl.ImageWidget(
    [corr, pnr], 
    names=["corr", "pnr"],
    grid_plot_kwargs={"size": (650, 300)},
    cmap="turbo",
)

# mcorr vids, we will display thresholded mcorr vids
mcorr_vids = [images.astype(np.float32) for i in range(4)]

# sync the threshold image widget with the corr-pnr plot
threshold_grid_plot_kwargs = {
    "controllers": [[iw_corr_pnr.gridplot["corr"].controller]*2]*2,
    "size": (650, 600)
}

iw_thres_movie = fpl.ImageWidget(
    mcorr_vids, 
    names=["over corr threshold", "over pnr threshold", "under corr threshold", "under pnr threshold"],
    # sync this with the corr-pnr plot
    grid_plot_kwargs=threshold_grid_plot_kwargs,
    cmap="gnuplot2"
)

# display threshold of the spatially filtered movie
def spatial_filter(frame):
    f = high_pass_filter_space(frame, (3, 3))
    return f


# threshold
def threshold(frame, mask):
    # optionally use spatial filter
    t = spatial_filter(frame)
    
    t = t.copy()
    
    t[mask] = t.min()
    
    return t

# Set the thresholded images using the vmin set from top subplots
# dict of threshold lambda wrappers to set on ImageWidget
# this sets the frame_apply for each subplot
threshold_funcs = {
    0: lambda frame: threshold(frame, corr < iw_corr_pnr.gridplot["corr"].graphics[0].cmap.vmin),
    1: lambda frame: threshold(frame, pnr < iw_corr_pnr.gridplot["pnr"].graphics[0].cmap.vmin),
    2: lambda frame: threshold(frame, corr > iw_corr_pnr.gridplot["corr"].graphics[0].cmap.vmin),
    3: lambda frame: threshold(frame, pnr > iw_corr_pnr.gridplot["pnr"].graphics[0].cmap.vmin)
}

# set the dict of lambda wrappers
iw_thres_movie.frame_apply = threshold_funcs

# update threshold plots when the corr pnr sliders move
def update_threshold_plots(*args):
    iw_thres_movie.current_index = iw_thres_movie.current_index

# this will get easier in the future
iw_corr_pnr.gridplot["corr"].docks["right"]["histogram_lut"].linear_region.selection.add_event_handler(update_threshold_plots)
iw_corr_pnr.gridplot["pnr"].docks["right"]["histogram_lut"].linear_region.selection.add_event_handler(update_threshold_plots)

#VBox([iw_corr_pnr.show(), iw_thres_movie.show()])
VBox([iw_corr_pnr.show()])
# Out:
# RFBOutputContext()
# /Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/fastplotlib/graphics/_features/_base.py:34: UserWarning: converting float64 array to float32
#   warn(f"converting {array.dtype} array to float32")
# RFBOutputContext()
# VBox(children=(JupyterOutputContext(children=(JupyterWgpuCanvas(css_width='650px'), IpywidgetToolBar(children=…
# 2023-11-15 11:44:36,024 - ERROR - [base.py log_exception() 37] - pid 42983 - Error during handling pointer_move event
# Traceback (most recent call last):
#   File "/Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/wgpu/gui/base.py", line 24, in log_exception
#     yield
#   File "/Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/pygfx/objects/_events.py", line 395, in handle_event
#     callback(event)
#   File "/Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/fastplotlib/graphics/selectors/_base_selector.py", line 237, in _move
#     self._move_graphic(self.delta)
#   File "/Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/fastplotlib/graphics/selectors/_linear_region.py", line 537, in _move_graphic
#     self.selection = (self.selection()[0], bound1_new)
#     ^^^^^^^^^^^^^^
#   File "/Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/fastplotlib/graphics/_base.py", line 139, in __setattr__
#     attr._set(value)
#   File "/Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/fastplotlib/graphics/_features/_selection_features.py", line 289, in _set
#     self._feature_changed(key=None, new_data=value)
#   File "/Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/fastplotlib/graphics/_features/_selection_features.py", line 319, in _feature_changed
#     self._call_event_handlers(event_data)
#   File "/Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/fastplotlib/graphics/_features/_base.py", line 187, in _call_event_handlers
#     func()
#   File "/var/folders/f3/11w5x6bs32gd1xc4lh41qdnr0000gp/T/ipykernel_42983/3486551886.py", line 58, in update_threshold_plots
#     iw_thres_movie.current_index = iw_thres_movie.current_index
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/fastplotlib/widgets/image.py", line 210, in current_index
#     self.sliders[k].value = index[k]
#     ^^^^^^^^^^^^
#   File "/Users/js0403/anaconda3/envs/mescore/lib/python3.11/site-packages/fastplotlib/widgets/image.py", line 162, in sliders
#     return self._image_widget_toolbar.sliders
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'sliders'
# 2023-11-15 11:44:36,056 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (2)
# 2023-11-15 11:44:36,105 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (3)
# 2023-11-15 11:44:36,143 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (4)
# 2023-11-15 11:44:36,149 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (5)
# 2023-11-15 11:44:39,389 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (6)
# 2023-11-15 11:44:39,407 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (7)
# 2023-11-15 11:44:39,473 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (8)
# 2023-11-15 11:44:39,575 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (9)
# 2023-11-15 11:44:39,633 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (10)
# 2023-11-15 11:44:39,638 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (11)
# 2023-11-15 11:44:39,665 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (12)
# 2023-11-15 11:44:39,725 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (13)
# 2023-11-15 11:44:39,746 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (14)
# 2023-11-15 11:44:39,760 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (15)
# 2023-11-15 11:44:40,083 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (16)
# 2023-11-15 11:44:40,133 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (17)
# 2023-11-15 11:44:40,300 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (18)
# 2023-11-15 11:44:40,331 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (19)
# 2023-11-15 11:44:40,355 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (20)
# 2023-11-15 11:44:40,369 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (21)
# 2023-11-15 11:44:40,425 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (22)
# 2023-11-15 11:44:40,464 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (23)
# 2023-11-15 11:44:40,471 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (24)
# 2023-11-15 11:44:40,523 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (25)
# 2023-11-15 11:44:40,527 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (26)
# 2023-11-15 11:44:40,578 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (27)
# 2023-11-15 11:44:40,582 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (28)
# 2023-11-15 11:44:40,601 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (29)
# 2023-11-15 11:44:40,646 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (30)
# 2023-11-15 11:44:40,668 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (31)
# 2023-11-15 11:44:40,673 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (32)
# 2023-11-15 11:44:40,679 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (33)
# 2023-11-15 11:44:40,751 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (34)
# 2023-11-15 11:44:40,757 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (35)
# 2023-11-15 11:44:40,781 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (36)
# 2023-11-15 11:44:40,813 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (37)
# 2023-11-15 11:44:40,870 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (38)
# 2023-11-15 11:44:42,044 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (39)
# 2023-11-15 11:44:42,060 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (40)
# 2023-11-15 11:44:42,109 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (41)
# 2023-11-15 11:44:42,114 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (42)
# 2023-11-15 11:44:42,181 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (43)
# 2023-11-15 11:44:42,204 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (44)
# 2023-11-15 11:44:42,220 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (45)
# 2023-11-15 11:44:42,224 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (46)
# 2023-11-15 11:44:42,297 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (47)
# 2023-11-15 11:44:42,302 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (48)
# 2023-11-15 11:44:42,322 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (49)
# 2023-11-15 11:44:42,415 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (50)
# 2023-11-15 11:44:42,446 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (51)
# 2023-11-15 11:44:42,608 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (52)
# 2023-11-15 11:44:42,668 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (53)
# 2023-11-15 11:44:42,672 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (54)
# 2023-11-15 11:44:42,682 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (55)
# 2023-11-15 11:44:42,755 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (56)
# 2023-11-15 11:44:42,775 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (57)
# 2023-11-15 11:44:42,780 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (58)
# 2023-11-15 11:44:42,791 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (59)
# 2023-11-15 11:44:42,865 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (60)
# 2023-11-15 11:44:43,200 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (61)
# 2023-11-15 11:44:43,238 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (62)
# 2023-11-15 11:44:43,253 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (63)
# 2023-11-15 11:44:43,307 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (64)
# 2023-11-15 11:44:43,327 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (65)
# 2023-11-15 11:44:43,342 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (66)
# 2023-11-15 11:44:43,593 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (67)
# 2023-11-15 11:44:43,643 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (68)
# 2023-11-15 11:44:43,683 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (69)
# 2023-11-15 11:44:43,715 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (70)
# 2023-11-15 11:44:43,754 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (71)
# 2023-11-15 11:44:43,758 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (72)
# 2023-11-15 11:44:43,812 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (73)
# 2023-11-15 11:44:43,823 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (74)
# 2023-11-15 11:44:43,876 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (75)
# 2023-11-15 11:44:44,167 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (76)
# 2023-11-15 11:44:44,183 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (77)
# 2023-11-15 11:44:44,234 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (78)
# 2023-11-15 11:44:44,254 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (79)
# 2023-11-15 11:44:44,274 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (80)
# 2023-11-15 11:44:44,337 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (81)
# 2023-11-15 11:44:44,370 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (82)
# 2023-11-15 11:44:44,408 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (83)
# 2023-11-15 11:44:44,412 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (84)
# 2023-11-15 11:44:44,466 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (85)
# 2023-11-15 11:44:44,477 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (86)
# 2023-11-15 11:44:44,532 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (87)
# 2023-11-15 11:44:44,606 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (88)
# 2023-11-15 11:44:44,620 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (89)
# 2023-11-15 11:44:44,674 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (90)
# 2023-11-15 11:44:44,710 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (91)
# 2023-11-15 11:44:44,780 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (92)
# 2023-11-15 11:44:44,816 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (93)
# 2023-11-15 11:44:44,841 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (94)
# 2023-11-15 11:44:44,890 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (95)
# 2023-11-15 11:44:44,924 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (96)
# 2023-11-15 11:44:44,929 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (97)
# 2023-11-15 11:44:44,982 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (98)
# 2023-11-15 11:44:45,309 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (99)
# 2023-11-15 11:44:51,442 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (100)
# 2023-11-15 11:44:51,479 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (101)
# 2023-11-15 11:44:51,499 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (102)
# 2023-11-15 11:44:51,517 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (103)
# 2023-11-15 11:44:51,574 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (104)
# 2023-11-15 11:44:51,594 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (105)
# 2023-11-15 11:44:51,715 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (106)
# 2023-11-15 11:44:51,752 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (107)
# 2023-11-15 11:44:51,788 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (108)
# 2023-11-15 11:44:51,809 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (109)
# 2023-11-15 11:44:51,823 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (110)
# 2023-11-15 11:44:51,865 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (111)
# 2023-11-15 11:44:52,091 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (112)
# 2023-11-15 11:44:52,191 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (113)
# 2023-11-15 11:44:52,226 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (114)
# 2023-11-15 11:44:52,261 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (115)
# 2023-11-15 11:44:52,286 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (116)
# 2023-11-15 11:44:52,320 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (117)
# 2023-11-15 11:44:52,347 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (118)
# 2023-11-15 11:44:52,410 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (119)
# 2023-11-15 11:44:52,613 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (120)
# 2023-11-15 11:44:52,649 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (121)
# 2023-11-15 11:44:52,682 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (122)
# 2023-11-15 11:44:52,717 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (123)
# 2023-11-15 11:44:52,724 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (124)
# 2023-11-15 11:44:52,787 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (125)
# 2023-11-15 11:44:52,806 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (126)
# 2023-11-15 11:44:52,809 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (127)
# 2023-11-15 11:44:52,815 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (128)
# 2023-11-15 11:44:52,879 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (129)
# 2023-11-15 11:44:52,884 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (130)
# 2023-11-15 11:44:52,887 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (131)
# 2023-11-15 11:44:52,929 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (132)
# 2023-11-15 11:44:52,959 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (133)
# 2023-11-15 11:44:52,980 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (134)
# 2023-11-15 11:44:53,026 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (135)
# 2023-11-15 11:44:53,331 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (136)
# 2023-11-15 11:44:53,373 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (137)
# 2023-11-15 11:44:53,411 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (138)
# 2023-11-15 11:44:53,431 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (139)
# 2023-11-15 11:44:53,445 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (140)
# 2023-11-15 11:44:53,499 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (141)
# 2023-11-15 11:44:53,574 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (142)
# 2023-11-15 11:44:53,614 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (143)
# 2023-11-15 11:44:53,651 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (144)
# 2023-11-15 11:44:53,675 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (145)
# 2023-11-15 11:44:53,730 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (146)
# 2023-11-15 11:44:53,785 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (147)
# 2023-11-15 11:44:55,532 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (148)
# 2023-11-15 11:44:55,801 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (149)
# 2023-11-15 11:44:55,836 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (150)
# 2023-11-15 11:44:55,878 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (151)
# 2023-11-15 11:44:55,885 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (152)
# 2023-11-15 11:44:55,910 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (153)
# 2023-11-15 11:44:55,969 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (154)
# 2023-11-15 11:44:55,989 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (155)
# 2023-11-15 11:44:56,006 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (156)
# 2023-11-15 11:44:56,026 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (157)
# 2023-11-15 11:44:56,158 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (158)
# 2023-11-15 11:44:56,206 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (159)
# 2023-11-15 11:44:56,259 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (160)
# 2023-11-15 11:44:56,275 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (161)
# 2023-11-15 11:44:56,340 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (162)
# 2023-11-15 11:44:56,351 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (163)
# 2023-11-15 11:44:56,417 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (164)
# 2023-11-15 11:44:56,437 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (165)
# 2023-11-15 11:44:56,443 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (166)
# 2023-11-15 11:44:56,451 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (167)
# 2023-11-15 11:44:56,491 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (168)
# 2023-11-15 11:44:56,518 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (169)
# 2023-11-15 11:44:56,539 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (170)
# 2023-11-15 11:44:56,570 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (171)
# 2023-11-15 11:44:56,583 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (172)
# 2023-11-15 11:44:56,613 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (173)
# 2023-11-15 11:44:56,643 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (174)
# 2023-11-15 11:44:56,658 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (175)
# 2023-11-15 11:44:56,662 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (176)
# 2023-11-15 11:44:56,688 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (177)
# 2023-11-15 11:44:56,723 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (178)
# 2023-11-15 11:44:56,813 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (179)
# 2023-11-15 11:44:56,817 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (180)
# 2023-11-15 11:44:56,822 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (181)
# 2023-11-15 11:44:56,893 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (182)
# 2023-11-15 11:44:57,029 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (183)
# 2023-11-15 11:44:57,086 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (184)
# 2023-11-15 11:44:57,106 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (185)
# 2023-11-15 11:44:57,149 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (186)
# 2023-11-15 11:44:57,307 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (187)
# 2023-11-15 11:44:57,339 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (188)
# 2023-11-15 11:44:57,372 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (189)
# 2023-11-15 11:44:57,405 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (190)
# 2023-11-15 11:44:57,428 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (191)
# 2023-11-15 11:44:57,440 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (192)
# 2023-11-15 11:44:57,496 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (193)
# 2023-11-15 11:44:57,528 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (194)
# 2023-11-15 11:44:57,570 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (195)
# 2023-11-15 11:44:58,049 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (196)
# 2023-11-15 11:44:58,096 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (197)
# 2023-11-15 11:44:58,139 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (198)
# 2023-11-15 11:44:58,144 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (199)
# 2023-11-15 11:44:58,167 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (200)
# 2023-11-15 11:44:58,229 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (201)
# 2023-11-15 11:44:58,249 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (202)
# 2023-11-15 11:44:58,267 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (203)
# 2023-11-15 11:44:58,312 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (204)
# 2023-11-15 11:44:58,340 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (205)
# 2023-11-15 11:44:58,355 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (206)
# 2023-11-15 11:44:58,518 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (207)
# 2023-11-15 11:44:58,554 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (208)
# 2023-11-15 11:44:58,590 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (209)
# 2023-11-15 11:44:58,595 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (210)
# 2023-11-15 11:44:58,648 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (211)
# 2023-11-15 11:44:58,661 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (212)
# 2023-11-15 11:44:58,710 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (213)
# 2023-11-15 11:44:58,831 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (214)
# 2023-11-15 11:44:58,863 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (215)
# 2023-11-15 11:44:58,886 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (216)
# 2023-11-15 11:44:58,920 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (217)
# 2023-11-15 11:44:59,428 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (218)
# 2023-11-15 11:44:59,484 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (219)
# 2023-11-15 11:45:00,992 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (220)
# 2023-11-15 11:45:01,035 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (221)
# 2023-11-15 11:45:01,071 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (222)
# 2023-11-15 11:45:01,075 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (223)
# 2023-11-15 11:45:01,117 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (224)
# 2023-11-15 11:45:01,157 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (225)
# 2023-11-15 11:45:01,216 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (226)
# 2023-11-15 11:45:01,220 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (227)
# 2023-11-15 11:45:01,230 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (228)
# 2023-11-15 11:45:01,293 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (229)
# 2023-11-15 11:45:01,306 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (230)
# 2023-11-15 11:45:01,326 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (231)
# 2023-11-15 11:45:01,376 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (232)
# 2023-11-15 11:45:01,397 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (233)
# 2023-11-15 11:45:01,412 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (234)
# 2023-11-15 11:45:01,416 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (235)
# 2023-11-15 11:45:01,489 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (236)
# 2023-11-15 11:45:01,492 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (237)
# 2023-11-15 11:45:01,511 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (238)
# 2023-11-15 11:45:01,564 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (239)
# 2023-11-15 11:45:01,584 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (240)
# 2023-11-15 11:45:01,736 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (241)
# 2023-11-15 11:45:01,770 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (242)
# 2023-11-15 11:45:01,775 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (243)
# 2023-11-15 11:45:01,823 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (244)
# 2023-11-15 11:45:01,827 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (245)
# 2023-11-15 11:45:01,880 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (246)
# 2023-11-15 11:45:01,900 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (247)
# 2023-11-15 11:45:01,916 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (248)
# 2023-11-15 11:45:01,958 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (249)
# 2023-11-15 11:45:02,001 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (250)
# 2023-11-15 11:45:02,005 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (251)
# 2023-11-15 11:45:02,234 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (252)
# 2023-11-15 11:45:02,287 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (253)
# 2023-11-15 11:45:02,383 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (254)
# 2023-11-15 11:45:02,808 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (255)
# 2023-11-15 11:45:02,844 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (256)
# 2023-11-15 11:45:02,877 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (257)
# 2023-11-15 11:45:02,902 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (258)
# 2023-11-15 11:45:02,937 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (259)
# 2023-11-15 11:45:02,959 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (260)
# 2023-11-15 11:45:02,976 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (261)
# 2023-11-15 11:45:03,028 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (262)
# 2023-11-15 11:45:03,388 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (263)
# 2023-11-15 11:45:03,435 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (264)
# 2023-11-15 11:45:03,463 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (265)
# 2023-11-15 11:45:03,497 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (266)
# 2023-11-15 11:45:03,502 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (267)
# 2023-11-15 11:45:03,542 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (268)
# 2023-11-15 11:45:03,555 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (269)
# 2023-11-15 11:45:03,593 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (270)
# 2023-11-15 11:45:03,661 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (271)
# 2023-11-15 11:45:03,898 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (272)
# 2023-11-15 11:45:03,932 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (273)
# 2023-11-15 11:45:03,956 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (274)
# 2023-11-15 11:45:03,992 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (275)
# 2023-11-15 11:45:04,045 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (276)
# 2023-11-15 11:45:04,081 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (277)
# 2023-11-15 11:45:04,118 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (278)
# 2023-11-15 11:45:04,161 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (279)
# 2023-11-15 11:45:05,749 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (280)
# 2023-11-15 11:45:05,769 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (281)
# 2023-11-15 11:45:05,824 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (282)
# 2023-11-15 11:45:05,828 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (283)
# 2023-11-15 11:45:05,842 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (284)
# 2023-11-15 11:45:05,913 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (285)
# 2023-11-15 11:45:05,936 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (286)
# 2023-11-15 11:45:05,988 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (287)
# 2023-11-15 11:45:06,025 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (288)
# 2023-11-15 11:45:06,044 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (289)
# 2023-11-15 11:45:06,059 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (290)
# 2023-11-15 11:45:06,119 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (291)
# 2023-11-15 11:45:06,123 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (292)
# 2023-11-15 11:45:06,210 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (293)
# 2023-11-15 11:45:06,252 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (294)
# 2023-11-15 11:45:06,288 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (295)
# 2023-11-15 11:45:06,321 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (296)
# ...
# 2023-11-15 11:45:12,924 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (384)
# 2023-11-15 11:45:12,957 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (385)
# 2023-11-15 11:45:12,995 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (386)
# 2023-11-15 11:45:12,999 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (387)
# 2023-11-15 11:45:13,011 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (388)
# 2023-11-15 11:45:13,078 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (389)
# 2023-11-15 11:45:13,098 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (390)
# 2023-11-15 11:45:13,110 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (391)
# 2023-11-15 11:45:13,162 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (392)
# 2023-11-15 11:45:13,182 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (393)
# 2023-11-15 11:45:13,195 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (394)
# 2023-11-15 11:45:13,245 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (395)
# 2023-11-15 11:45:13,264 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (396)
# 2023-11-15 11:45:13,277 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (397)
# 2023-11-15 11:45:13,880 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (398)
# 2023-11-15 11:45:13,896 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (399)
# 2023-11-15 11:45:13,949 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (400)
# 2023-11-15 11:45:13,968 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (401)
# 2023-11-15 11:45:16,048 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (402)
# 2023-11-15 11:45:16,101 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (403)
# 2023-11-15 11:45:16,136 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (404)
# 2023-11-15 11:45:16,141 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (405)
# 2023-11-15 11:45:16,181 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (406)
# 2023-11-15 11:45:16,195 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (407)
# 2023-11-15 11:45:16,252 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (408)
# 2023-11-15 11:45:16,271 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (409)
# 2023-11-15 11:45:16,308 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (410)
# 2023-11-15 11:45:16,324 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (411)
# 2023-11-15 11:45:16,344 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (412)
# 2023-11-15 11:45:16,397 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (413)
# 2023-11-15 11:45:16,418 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (414)
# 2023-11-15 11:45:16,435 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (415)
# 2023-11-15 11:45:16,455 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (416)
# 2023-11-15 11:45:16,549 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (417)
# 2023-11-15 11:45:16,565 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (418)
# 2023-11-15 11:45:16,616 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (419)
# 2023-11-15 11:45:16,730 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (420)
# 2023-11-15 11:45:16,757 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (421)
# 2023-11-15 11:45:16,796 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (422)
# 2023-11-15 11:45:16,817 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (423)
# 2023-11-15 11:45:16,836 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (424)
# 2023-11-15 11:45:16,890 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (425)
# 2023-11-15 11:45:16,928 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (426)
# 2023-11-15 11:45:16,997 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (427)
# 2023-11-15 11:45:17,072 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (428)
# 2023-11-15 11:45:17,105 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (429)
# 2023-11-15 11:45:17,109 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (430)
# 2023-11-15 11:45:17,163 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (431)
# 2023-11-15 11:45:17,167 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (432)
# 2023-11-15 11:45:17,212 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (433)
# 2023-11-15 11:45:17,239 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (434)
# 2023-11-15 11:45:17,279 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (435)
# 2023-11-15 11:45:17,296 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (436)
# 2023-11-15 11:45:17,475 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (437)
# 2023-11-15 11:45:17,608 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (438)
# 2023-11-15 11:45:17,657 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (439)
# 2023-11-15 11:45:17,674 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (440)
# 2023-11-15 11:45:17,730 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (441)
# 2023-11-15 11:45:18,087 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (442)
# 2023-11-15 11:45:18,128 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (443)
# 2023-11-15 11:45:18,144 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (444)
# 2023-11-15 11:45:18,198 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (445)
# 2023-11-15 11:45:18,218 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (446)
# 2023-11-15 11:45:18,235 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (447)
# 2023-11-15 11:45:18,326 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (448)
# 2023-11-15 11:45:18,363 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (449)
# 2023-11-15 11:45:18,456 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (450)
# 2023-11-15 11:45:18,484 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (451)
# 2023-11-15 11:45:18,519 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (452)
# 2023-11-15 11:45:18,540 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (453)
# 2023-11-15 11:45:18,556 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (454)
# 2023-11-15 11:45:18,613 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (455)
# 2023-11-15 11:45:18,645 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (456)
# 2023-11-15 11:45:18,686 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (457)
# 2023-11-15 11:45:18,722 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (458)
# 2023-11-15 11:45:18,743 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (459)
# 2023-11-15 11:45:18,798 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (460)
# 2023-11-15 11:45:18,974 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (461)
# 2023-11-15 11:45:19,018 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (462)
# 2023-11-15 11:45:19,022 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (463)
# 2023-11-15 11:45:19,156 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (464)
# 2023-11-15 11:45:19,192 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (465)
# 2023-11-15 11:45:19,218 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (466)
# 2023-11-15 11:45:19,253 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (467)
# 2023-11-15 11:45:19,274 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (468)
# 2023-11-15 11:45:19,315 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (469)
# 2023-11-15 11:45:19,351 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (470)
# 2023-11-15 11:45:19,355 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (471)
# 2023-11-15 11:45:19,409 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (472)
# 2023-11-15 11:45:19,452 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (473)
# 2023-11-15 11:45:19,461 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (474)
# 2023-11-15 11:45:19,518 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (475)
# 2023-11-15 11:45:19,538 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (476)
# 2023-11-15 11:45:19,557 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (477)
# 2023-11-15 11:45:19,603 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (478)
# 2023-11-15 11:45:19,615 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (479)
# 2023-11-15 11:45:19,654 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (480)
# 2023-11-15 11:45:19,668 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (481)
# 2023-11-15 11:45:19,705 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (482)
# 2023-11-15 11:45:19,887 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (483)
# 2023-11-15 11:45:19,936 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (484)
# 2023-11-15 11:45:20,005 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (485)
# 2023-11-15 11:45:20,031 - ERROR - [base.py log_exception() 43] - pid 42983 - Error during handling pointer_move event: 'NoneType' object has no at… (486)

# %% [markdown]
# # Automatic assignment of min_corr and min_pnr

# %%
corr_pnr_inputs = {
    'min_corr': iw_corr_pnr.gridplot["corr"].graphics[0].cmap.vmin, # corr value from previous plot
    'min_pnr': iw_corr_pnr.gridplot["pnr"].graphics[0].cmap.vmin,  # PNR value from previous plot
}
corr_pnr_inputs
# Out:
# {'min_corr': 0.49309247732162476, 'min_pnr': 2.5695302486419678}

# %%
corr_pnr_inputs['min_corr']
# Out:
# 0.49309247732162476

# %% [markdown]
# # Parameter setting for CNMF-E
# Everything is now set up to run source extraction with CNMFE. We will construct a new parameter dictionary and use this to modify the *existing* `parameters` object, using the `change_params()` method.
#
# There are *two* main differences between the CNMF and CNMFE source separation algorithms. The first is the background model (this is discussed in the sidebar below on the Ring Model). The second difference is in how the models are initialized. This is addressed below when we go over setting corr/pnr thresholds for initialization, which we did not have to do for our 2p data.
#
# We will explain the important differences in more detail below. For now, note that we have set `gnb` to `0`: this is effectively the flag telling Caiman to use CNMFE instead of CNMF.

# %%
gSig_val
# Out:
# 13

# %% [markdown]
# # Catching an error on gSig - fix
# bord_pix

# %%
# parameters for source extraction and deconvolution
p = 1               # order of the autoregressive system
K = None            # upper bound on number of components per patch, in general None for CNMFE
gSig = gSig_val  # expected half-width of neurons in pixels 
gSiz = 2*gSig_val + 1     # half-width of bounding box created around neurons during initialization
merge_thr = .7      # merging threshold, max correlation allowed
rf = 40             # half-size of the patches in pixels. e.g., if rf=40, patches are 80x80
stride_cnmf = stride    # amount of overlap between the patches in pixels 
tsub = 2            # downsampling factor in time for initialization, increase if you have memory problems
ssub = 1            # downsampling factor in space for initialization, increase if you have memory problems
gnb = 0             # number of background components (rank) if positive, set to 0 for CNMFE
low_rank_background = None  # None leaves background of each patch intact (use True if gnb>0)
nb_patch = 0        # number of background components (rank) per patch (0 for CNMFE)
min_corr = corr_pnr_inputs['min_corr']       # min peak value from correlation image
min_pnr = corr_pnr_inputs['min_pnr']       # min peak to noise ration from PNR image
ssub_B = 2          # additional downsampling factor in space for background (increase to 2 if slow)
ring_size_factor = 1.4  # radius of ring is gSiz*ring_size_factor

parameters.change_params(params_dict={'method_init': 'corr_pnr',  # use this for 1 photon
                                'K': K,
                                'gSig': gSig,
                                'gSiz': gSiz,
                                'merge_thr': merge_thr,
                                'p': p,
                                'tsub': tsub,
                                'ssub': ssub,
                                'rf': rf,
                                'stride': stride_cnmf,
                                'only_init': True,    # set it to True to run CNMF-E
                                'nb': gnb,
                                'nb_patch': nb_patch,
                                'method_deconvolution': 'oasis',       # could use 'cvxpy' alternatively
                                'low_rank_background': low_rank_background,
                                'update_background_components': True,  # sometimes setting to False improve the results
                                'min_corr': min_corr,
                                'min_pnr': min_pnr,
                                'normalize_init': False,               # just leave as is
                                'center_psf': True,                    # True for 1p
                                'ssub_B': ssub_B,
                                'ring_size_factor': ring_size_factor,
                                'del_duplicates': True,                # whether to remove duplicates from initialization
                                'border_pix': bord_px})                # number of pixels to not consider in the borders)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb Cell 33 line 1
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=15'>16</a> ssub_B = 2          # additional downsampling factor in space for background (increase to 2 if slow)
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=16'>17</a> ring_size_factor = 1.4  # radius of ring is gSiz*ring_size_factor
# ---> <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=18'>19</a> parameters.change_params(params_dict={'method_init': 'corr_pnr',  # use this for 1 photon
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=19'>20</a>                                 'K': K,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=20'>21</a>                                 'gSig': gSig,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=21'>22</a>                                 'gSiz': gSiz,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=22'>23</a>                                 'merge_thr': merge_thr,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=23'>24</a>                                 'p': p,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=24'>25</a>                                 'tsub': tsub,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=25'>26</a>                                 'ssub': ssub,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=26'>27</a>                                 'rf': rf,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=27'>28</a>                                 'stride': stride_cnmf,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=28'>29</a>                                 'only_init': True,    # set it to True to run CNMF-E
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=29'>30</a>                                 'nb': gnb,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=30'>31</a>                                 'nb_patch': nb_patch,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=31'>32</a>                                 'method_deconvolution': 'oasis',       # could use 'cvxpy' alternatively
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=32'>33</a>                                 'low_rank_background': low_rank_background,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=33'>34</a>                                 'update_background_components': True,  # sometimes setting to False improve the results
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=34'>35</a>                                 'min_corr': min_corr,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=35'>36</a>                                 'min_pnr': min_pnr,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=36'>37</a>                                 'normalize_init': False,               # just leave as is
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=37'>38</a>                                 'center_psf': True,                    # True for 1p
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=38'>39</a>                                 'ssub_B': ssub_B,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=39'>40</a>                                 'ring_size_factor': ring_size_factor,
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=40'>41</a>                                 'del_duplicates': True,                # whether to remove duplicates from initialization
#      <a href='vscode-notebook-cell:/Users/js0403/decode_lab_code/scripts_and_notebooks/projects/miniscope/134A_CNMFE_MESMERIZE.ipynb#X31sZmlsZQ%3D%3D?line=41'>42</a>                                 'border_pix': bord_px})                # number of pixels to not consider in the borders)
#
# File ~/anaconda3/envs/mescore/lib/python3.11/site-packages/caiman/source_extraction/cnmf/params.py:1072, in CNMFParams.change_params(self, params_dict, verbose)
#    1070     if flag:
#    1071         logging.warning('No parameter {0} found!'.format(k))
# -> 1072 self.check_consistency()
#    1073 return self
#
# File ~/anaconda3/envs/mescore/lib/python3.11/site-packages/caiman/source_extraction/cnmf/params.py:919, in CNMFParams.check_consistency(self)
#     917 if self.init['gSiz'] is None:
#     918     self.init['gSiz'] = [2*gs + 1 for gs in self.init['gSig']]
# --> 919 self.init['gSiz'] = tuple([gs + 1 if gs % 2 == 0 else gs for gs in self.init['gSiz']])
#     920 if self.patch['rf'] is not None:
#     921     if np.any(np.array(self.patch['rf']) <= self.init['gSiz'][0]):
#
# TypeError: 'int' object is not iterable

# %%
cnmfe_model = cnmf.CNMF(n_processes=n_processes, 
                        dview=cluster, 
                        params=parameters)

# %% [markdown]
# <div class="alert alert-info">
#     <h2 >CNMF-E: The Ring Model</h2>
#    <p>Background activity is very ill-behaved with 1p recordings: it often fluctuates locally and is much larger in magnitude than the neural signals we want to extract. In other words, the large-scale background model used for CNMF is not sufficient for most 1p data. Hence, Pengcheng Zhou and others came up with a localized model of background activity for CNMFE: CNMFE represents the background at each pixel as the weighted sum of activity from a circle (or ring) of pixels a certain distance from that pixel. The distance of this ring from the reference pixel is set by the <em>ring_size_factor</em> parameter. This more complex pixel-wise background model explains why CNMFE is computationally more expensive than CNMF, and also why it works better to mop up large-scale localized background noise to find the neurons in your 1p data.</p>
#
# <p>When you set <em>gnb</em> in the CNMF model (usually to 1 or 2), you are setting the number of global background components to use. The fact that you can get away with so few is testament to how well-behaved the background activity is in 2p recordings compared to 1p. When we set <em>gnb</em> to 0 in Caiman, this is a flag telling Caiman's back end to switch to the ring model of the background activity.</p>
#
# For more details on CNMFE you can see the <a href="https://elifesciences.org/articles/28728">original paper</a> and the <a href="https://elifesciences.org/articles/38173">Caiman paper</a>.
# </div>

# %% [markdown]
# ## Key parameters for CNMFE
# The key parameters for CNMFE are slightly different than for CNMF, but with some overlap. As we'll see, because of the high levels of background activity, we can't initialize the same way as with CNMF. We have two new extremely important parameters directly related to initialization that come into play.

# %% [markdown]
# `rf` (int): *patch half-width*
# > `rf`, which stands for 'receptive field', is the half width of patches in pixels. The patch width is `2*rf + 1`. `rf` should be *at least* 3-4 times larger than the observed neuron diameter. The larger the patch size, the less parallelization will be used by Caiman. If `rf` is set to `None`, then CNMFE will be run on the entire field of view.
#
# `stride_cnmf (int)`: *patch overlap*
# > `stride_cnmf` is the overlap between patches in pixels (the actual overlap is `stride_cnmf + 1`). This should be at least the diameter of a neuron. The larger the overlap, the greater the computational load, but the results will be more accurate when stitching together results from different patches. This param should probably have been called 'overlap' instead of 'stride'.
#
# `gSig (int, int)`: *half-width of neurons*
# > `gSig` is roughly the half-width of neurons in your movie in pixels (height, width). It is the standard deviation of the mean-centered Gaussian used to filter the movie before initialization for CNMFE. It is related to the `gSiz` parameter, which is the size (in pixels) of a bounding box created around each seed pixel during initilialization. You will usually set `gSiz` to between `2*gSig` and `4*gSig` for CNMFE.
#
# `merge_thr (float)`: *merge threshold*
# > If the correlation between two spatially overlapping components is above `merge_thr`, they will be merged into one component.
#
# `min_corr` (float): *minimum correlation*
# > Pixels from neurons tend to be correlated with their neighbors. For initialization we select for pixels above a minimum correlation `min_corr`.  We discuss this more below.
#
# `min_pnr` (float): *minimum peak to noise ratio*
# > Set a threshoild peak-to-noise ratio. Pixels from neurons tend to have a high signal-to-noise ratio. For initialization we select for pixels above a minimum peak-to-noise-ratio `min_pnr`. We discuss this more below.
#
# As we did in `demo_pipeline.ipynb`, let's define a convenience function to get these key params for cnmfe so we can print them as we iteratively muck about in paramter space:

# %%
def key_params_cnmfe(cnmfe_model):
    """
    Convenience function to return critical parameters given CNMFE estimator object.
    Returns dict with values of rf, stride, gSig, gSiz, merge_threshold, min_corr, min_pnr
    
    Note: 
    gSiz is included because it depends on gSig and you want to make sure to change it when you change gSig.
    These are not set in stone: tweak for your own needs!
    """
    rf = cnmfe_model.params.patch['rf']
    stride = cnmfe_model.params.patch['stride']
    gSig = cnmfe_model.params.init['gSig']
    gSiz = cnmfe_model.params.init['gSiz']
    merge_thr = cnmfe_model.params.merging['merge_thr']
    min_corr = cnmfe_model.params.init['min_corr']
    min_pnr = cnmfe_model.params.init['min_pnr']
    
    
    key_params = {'min_corr': min_corr,    
                  'min_pnr': min_pnr,
                  'rf': rf, 
                  'stride': stride,
                  'gSig': gSig,
                  'gSiz': gSiz,
                  'merge_thr': merge_thr}
    
    return key_params

# %% [markdown]
# ## Inspect summary images and set parameters
# ### Correlation-pnr plot
# For CNMFE, Caiman uses the correlation and peak-to-noise (PNR) ratio for initialization, which will both tend to be high in regions that contain neurons. Hence, we set a threshold for both quantitites to remove the low correlation/low pnr regions, and highlight the regions higher in both metrics, those regions most likely to contain neuronal activity.
#
# First, we calculate the correlation and pnr maps of the raw motion corrected movie after filtering with a mean-centered Gaussian with standard deviation `gSig` (for more information, see the sidebar below). These calculation can be computationally and memory demanding for large datasets, so we subsample if there are many thousands of frames:

# %%
print(gSig)
gsig_tmp = (3,3)
correlation_image, peak_to_noise_ratio = cm.summary_images.correlation_pnr(images[::max(T//1000, 1)], # subsample if needed
                                                                           gSig=gsig_tmp[0], # used for filter
                                                                           swap_dim=False) # change swap dim if output looks weird, it is a problem with tiffile

# %% [markdown]
# <img src="https://raw.githubusercontent.com/EricThomson/image_sandbox/main/images/bokeh_menu.jpg" align="right" width="200"></img>
# Using `nb_inspect_correlation_pnr()`, you can inspect the correlation and PNR images to find reasonable threshold values for `min_corr` and `min_pnr`. You can adjust the range of values displayed in the plots shown below by choosing the Y-box select tool (third button from the left -- highlighted in yellow in the accompanying image) and selecting the desired region in the histograms to the right of each image. You can also use the pan button (first button on the left) to zoom/adjust the axis limits in the histogram to make it easier to see the limits.

# %%
def nb_inspect_correlation_pnr(corr, pnr, cmap='jet', num_bins=100):
    """
    inspect correlation and pnr images to infer the min_corr, min_pnr for cnmfe

    Args:
        corr: ndarray
            correlation image created with caiman.summary_images.correlation_pnr

        pnr: ndarray
            peak-to-noise image created with caiman.summary_images.correlation_pnr

        cmap: string
            colormap used for plotting corr and pnr images
            For valid colormaps see https://holoviews.org/user_guide/Colormaps.html

        num_bins: int
            number of bins to use for plotting histogram of corr/pnr values

    Returns:
        Holoviews plot layout (typically just plots in notebook)
    """
    import functools as fct
    hv_corr = hv.Image(corr,
                       vdims='corr',
                       label='correlation').opts(cmap=cmap)
    hv_pnr = hv.Image(pnr,
                      vdims='pnr',
                      label='pnr').opts(cmap=cmap)

    def hist(im, rx, ry, num_bins=num_bins):
        obj = im.select(x=rx, y=ry) if rx and ry else im
        return hv.operation.histogram(obj, num_bins=num_bins)

    str_corr = (hv.streams.RangeXY(source=hv_corr).rename(x_range='rx', y_range='ry'))
    str_pnr = (hv.streams.RangeXY(source=hv_pnr).rename(x_range='rx', y_range='ry'))

    hist_corr = hv.DynamicMap(
        fct.partial(hist, im=hv_corr), streams=[str_corr])

    hist_pnr = hv.DynamicMap(
        fct.partial(hist, im=hv_pnr), streams=[str_pnr])

    hv_layout = (hv_corr << hist_corr) + (hv_pnr << hist_pnr)

    return hv_layout

# %%
nb_inspect_correlation_pnr(correlation_image, peak_to_noise_ratio, cmap='inferno') # jet, fire are also good cmaps

# %% [markdown]
# We are looking for a couple of things in the above plot:
# 1) Did we filter with a `gSig` value small enough so that we aren't blending different neurons together? To see what it is like when this happens, set `gsig_tmp` to `(6,6)` and inspect the above plots.
# 2) More importantly, we want to find the threshold correlation and pnr values so that the *lower* threshold eliminates most of the noise and blood vessels from the plots, leaving behind as many of the neural pixels as possible. For this data it will be at a correlation value lower bound between 0.8 and 0.9, and and pnr lower bound somewhere between 10 and 20 (as with CNMF, there is no perfect value: it is often an iterative search, but keep in mind it is better to have false positives later than false negatives).
#
# You can tweak the parameters in the following cell (included are some values that are reasonable):

# %%
print(key_params_cnmfe(cnmfe_model))

gsig_new = gSig # unchanged
min_corr_new  = 0.85 
min_pnr_new = 12     

cnmfe_model.params.change_params(params_dict={'gSig': gsig_new,
                                              'min_corr': min_corr_new, 
                                              'min_pnr': min_pnr_new});

print(key_params_cnmfe(cnmfe_model))

# %% [markdown]
# > Caiman also includes a Qt-based corr-pnr viewer that some people prefer: `inspect_correlation_pnr()`. It provides what some say is a more intuitive interface than the notebook version above. It requires you to be in Qt mode (which you can enable using the cell magic `%matplotlib qt`).

# %% [markdown]
# <div class="alert alert-info">
#     <h2>CNMFE initialization: More on correlation and peak-to-noise-ratio</h2>
# <img src="https://raw.githubusercontent.com/EricThomson/image_sandbox/main/images/mn_centered_gaussian.jpg" align="right" width="200"></img>
# <p></p>How are correlation and peak-to-noise ratio actually calculated? First Caiman convolves the motion corrected movie with a <i>mean-centered Gaussian</i> (example to the right). The sigma of the Gaussian is <em>gSig</em>, and mean centering is turned on by setting <em>center_psf</em> to <em>True</em>. This mean centering creates a Gaussian with a positive peak in the middle of width <i>approximately</i> <em>gSig/2</em>, surrounded by a negative trench, and sets the outer edge to be zero. This preprocessing filter serves to highlight neuronal peaks and smooth away low-frequency background components.</p>
#
# <p>The function <em>correlation_pnr()</em> applies this mean-centered Gaussian to each frame of the motion corrected movie and returns the correlation image of that movie, as well as the peak-to-noise-ratio (PNR). The correlation image is the correlation of each pixel with its neighbors. The PNR is the ratio of the maximum magnitude at a pixel to the noise value at that pixel (it is a fast and rough measure of signal-to-noise). As mentioned above, both of these values tend to be higher in actual neurons, and the CNMFE initialization procedure is to set a threshold for both quantities, take their <i>product</i>, and use the peaks in this product map to find <i>seed pixels</i> for initialization of the CNMFE source separation algorithm.</p>
#
# <p>More details on the initialization procedure used here can be found in the <a href="https://elifesciences.org/articles/28728">CNMFE paper</a>, or just by exploring the code.</p>
# </div>

# %% [markdown]
# ### Quilt plot for spatial parameters
# As discussed in `demo_pipeline.ipynb`, the other important paramters are those used for dividing the movie into patches for parallelization of source separation. The same processe is used for CNMFE. Namely, select `rf` and `stride` parameters so that many neurons fit in each patch, and at least one neuron fits in the overlap region between patches. You can visualize the patches using the `view_quilt()` function:

# %%
# calculate stride and overlap from parameters
cnmfe_patch_width = cnmfe_model.params.patch['rf']*2 + 1
cnmfe_patch_overlap = cnmfe_model.params.patch['stride'] + 1
cnmfe_patch_stride = cnmfe_patch_width - cnmfe_patch_overlap
print(f'Patch width: {cnmfe_patch_width} , Stride: {cnmfe_patch_stride}, Overlap: {cnmfe_patch_overlap}');

# plot the patches
patch_ax = view_quilt(correlation_image, 
                      cnmfe_patch_stride, 
                      cnmfe_patch_overlap, 
                      vmin=np.percentile(np.ravel(correlation_image),50), 
                      vmax=np.percentile(np.ravel(correlation_image),99.5),
                      color='white',
                      figsize=(4,4));
patch_ax.set_title(f'CNMFE Patch Width {cnmfe_patch_width}, Overlap {cnmfe_patch_overlap}');

# %% [markdown]
# These patches and overlaps are large side, but that is ok: our main concern is that they not be too small. The `demo_notebook.ipynb` goes through in some detail adjusting the spatial parameters, as we did above for the initialization params. The process would be the same here if you needed to change the patch parameters for your data.
#
# Now that we are happy with our parameters, let's run the algorithm.

# %% [markdown]
# ## Run the CNMF-E algorithm

# %%
# %%time
cnmfe_model.fit(images);

# %% [markdown]
# Running the algorithm creates an `estimates` class, which we discuss in detail in `demo_pipeline.ipynb`. The CNMFE `estimates` class includes almost all the same attributes as with CNMF, such as the neural spatial and temporal components `A` and `C`.
#
# It also includes the discovered model of background activity, which in this case is different from the CNMF model. For CNMF the background model is returned as low-rank matrices `b` and `f`. For CNMFE, the background model parameters are represented in the matrix `W` (the weights of the *ring model* for each pixel) as well as `b0` (the constant offset for each pixel). We will show how to reconstruct the background activity below.

# %% [markdown]
# <div class="alert alert-info">
#     <h2>Run all of the above with one command</h2>
#     <p></p>It is possible to run the combined steps of motion correction, memory mapping, and cnmfe fitting using the <em>fit_file()</em> method. We recommend that you familiarize yourself with the various steps and the results of the various steps before using it.</p>
#
#     cnmfe_all = cnmf.CNMF(n_processes, params=parameters, dview=cluster)
#     cnmfe_all.fit_file(motion_correct=motion_correct)
#
# <p>It is most useful in the context of testing, or if sending jobs to a cluster.</p>

# %% [markdown]
# # Component Evaluation
# Source extraction typically produces many false positives. Our next step is quality control: separating the results into "good" and "bad" neurons using two different metrics (discussed in detail in `demo_notebook.ipynb`):
#
# - **Signal-to-noise ratio (SNR)**: a minimum SNR is set for the calcium transients (`min_SNR`).
# - **Spatial correlation**:  a minimum correlation is set between the shape of each component and the frames in the movie when that component is active (`rval_thr`).
#
# > Caiman does *not* use the CNN classifier to sort neurons based on shape for 1p data: the network was trained on 2p data. Hence, we set the `use_cnn` param to `False`.
#
# Here we set the two parameters and run `evaluate_components()` to see which pass muster:

# %%
min_SNR = 3            # SNR threshold
rval_thr = 0.85    # spatial correlation threshold

quality_params = {'min_SNR': min_SNR,
                  'rval_thr': rval_thr,
                  'use_cnn': False}
cnmfe_model.params.change_params(params_dict=quality_params)

cnmfe_model.estimates.evaluate_components(images, cnmfe_model.params, dview=cluster)

print('*****')
print(f"Total number of components: {len(cnmfe_model.estimates.C)}")
print(f"Number accepted: {len(cnmfe_model.estimates.idx_components)}")
print(f"Number rejected: {len(cnmfe_model.estimates.idx_components_bad)}")

# %% [markdown]
# # Visualize results

# %%
#%% plot contour plots of accepted and rejected components
cnmfe_model.estimates.plot_contours_nb(img=correlation_image, 
                                       idx=cnmfe_model.estimates.idx_components);

# %% [markdown]
# These components look reasonable, if a bit large -- their centers are reasonable but the spatial footprints are quite spread out. If I were persuing this further, it would likely be helpful to re-run CNMFE reducing `gSiz` a bit, which can influence the overall "spread" of the neurons in space.
#
# View traces of accepted and rejected components:

# %%
cnmfe_model.estimates.nb_view_components(img=correlation_image, 
                                        idx=cnmfe_model.estimates.idx_components,
                                        cmap='viridis', #gray
                                        thr=.9); #increase to see full footprint

# %%
# rejected components
cnmfe_model.estimates.nb_view_components(img=correlation_image, 
                                        idx=cnmfe_model.estimates.idx_components_bad,
                                        cmap='viridis', #gray
                                        denoised_color='red',
                                        thr=0.8); #increase to see full footprint

# %% [markdown]
# # Save and load results (optional)
# If you want to save your results so you don't have to run CNMFE again:

# %%
save_results = True
if save_results:
    save_path =  r'demo_pipeline_cnmfe_results.hdf5'  # or add full/path/to/file.hdf5
    cnmfe_model.estimates.Cn = correlation_image # squirrel away correlation image with cnmf object
    cnmfe_model.save(save_path)

# %% [markdown]
# To load results and pick up where you left off (note this assumes you have done preliminaries like imports and started a cluster).

# %%
load_results = True
if load_results:
    save_path =  r'demo_pipeline_cnmfe_results.hdf5'  # or add full/path/to/file.hdf5
    cnmfe_model = load_CNMF(save_path, 
                                n_processes=num_processors_to_use, 
                                dview=cluster)
    correlation_image = cnmfe_model.estimates.Cn
    print(f"Successfully loaded data.")

# %% [markdown]
# # A few loose ends
# We have extracted the calcium traces C, spatial footprints A, and estimated spike counts S, which is the main goal with CNMF. But there are a few important things remaining.
#
# ##  Deconvolution for 1p?
# While we haven't discussed deconvolution (the estimation of the spikes that generated the calcium traces in `C`), we suggest treating the spike counts returned for 1p data (in `estimates.S`) with CNMFE with some caution. Currently (as of Fall 2023) we are aware of no no ground-truth data that compares 1p recordings with actual spiking data. There is a *lot* of such data for 2p data, which allows for great comparison of different methods (for instance see [the Spikefinder paper](https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1006157)).
#
# Because of this, most researchers analyze the calcium traces directly for 1p recordings (the data in `estimates.C`) or a normalized version of them.

# %% [markdown]
# ## Extract $\Delta F/F$ values
# Currently in Caiman, we don't return a true dfof value for 1p data because Caiman normalizes to both the baseline fluorescence and background activity, and the background activity in 1p is so ill-behaved (as discussed above in the sidebar on the ring model). This is likely to change soon, but we currently only *detrend* the data (which will eliminate effects of photobleaching and other long-term artifacts) but do not normalize to baseline (which explains the warning you will see when you run the following):

# %%
if cnmfe_model.estimates.F_dff is None:
    print('Calculating estimates.F_dff')
    cnmfe_model.estimates.detrend_df_f(quantileMin=8, 
                                      frames_window=250,
                                      use_residuals=False);  # use denoised data
else:
    print("estimates.F_dff already defined")

# %% [markdown]
# ## View some different movie results
# As with CNMF, the CNMFE model of the original movie is:
#
#     original_movie = neural_activity + background + residual
#
# The main between CNMF and CNMFE is the model of the background. We can reconstruct the neural movie as `AC` just as we did in `demo_pipeline.ipynb`. Unfortunately, reconstructing the background activity via the ring model is much more complicated for CNMFE, so we will just punt to a built-in function for that in what follows (`compute_background()`).

# %%
# in case you are working from loaded data, recover the raw movie
Yr, dims, num_frames = cm.load_memmap(cnmfe_model.mmap_file)
images = np.reshape(Yr.T, [num_frames] + list(dims), order='F')

# %% [markdown]
# Get model of neural activity and background activity (note for the neural model we are just including the accepted components):

# %%
neural_activity = cnmfe_model.estimates.A[:, cnmfe_model.estimates.idx_components] @\
                  cnmfe_model.estimates.C[cnmfe_model.estimates.idx_components, :]  # AC
neural_movie = cm.movie(neural_activity).reshape(dims + (-1,), order='F').transpose([2, 0, 1])
background_model = cnmfe_model.estimates.compute_background(Yr);  # build in function -- explore source code for details
bg_movie = cm.movie(background_model).reshape(dims + (-1,), order='F').transpose([2, 0, 1])

# %% [markdown]
# To view just the movie of pure neural activity:

# %%
downsampling_ratio = 0.4 
neural_movie.resize(fz=downsampling_ratio).play(gain=1.1,
                                            q_max=99.5, 
                                            fr=20,
                                            plot_text=True,
                                            magnification=2,
                                            do_loop=False,
                                            backend='opencv')

# %% [markdown]
# Next we can view just the background model. You will see many regions that are constant such as blood vessels, but also lots of large-scale background flourescence, and some local activity which is is on spatial scales larger than `gSig`:

# %%
downsampling_ratio = 0.8 
bg_movie.resize(fz=downsampling_ratio).play(gain=1.1,
                                            q_max=99.5, 
                                            fr=10,
                                            plot_text=True,
                                            magnification=2,
                                            do_loop=False,
                                            backend='opencv')

# %% [markdown]
# We can also use the built-in `play_movie()` method to view the original movie, predicted movie, and the residual simultaneously as discussed in more detail in `demo_pipeline.ipynb`:

# %%
# without background
cnmfe_model.estimates.play_movie(images, 
                                 q_max=99.9, 
                                 magnification=2,
                                 include_bck=False,
                                 gain_res=5,
                                 use_color=True);

# %% [markdown]
# A couple of things to note about that movie:
# - The middle panel of neural activity includes *all* components (accepted and rejected), so you will see some of the blood vessel "activity" that was discovered and later rejected.
# - The residual includes some activity that looks neural in origin. You can try playing with different params to get them (which do you think you would try?). The [Mesmerize](https://github.com/nel-lab/mesmerize-core) package is a great way to search parameter space and visualize results with more sophisticated visualization tools if you have a tricky data set.

# %% [markdown]
# # Clean up open resourses
# Shut down server, close logger.

# %%
cm.stop_server(dview=cluster)

# %%
# Shut down logger (otherwise will not be able to delete it)
logging.shutdown()

# %%
delete_logs = True
logging_dir = cm.paths.get_tempdir() 
if delete_logs:
    log_files = glob.glob(logging_dir + '\\demo_pipeline' + '*' + '.log')
    for log_file in log_files:
        print(f"Deleting {log_file}")
        os.remove(log_file)
else:
    print(f"If you want to inspect your logs they are in {logging_dir}")
