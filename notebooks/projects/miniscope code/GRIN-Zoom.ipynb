# %% [markdown]
# # Zoom on GRIN window before analysis
#
# When recording with miniscope, you may end up having a lot of 'dead space' due to GRIN lens size. This dead space can actually impact things like motion correction and CNMFE because it is pixel-based analysis.
#
# ### Before analysis, you want to zoom in on your GRIN lens window
# ___
#
# Define your fname (session with recording), then run the code below

# %%
import tifffile
import matplotlib.pyplot as plt

# define movie paths
fname = '/Users/js0403/miniscope/data/122B/AAV2/3-Syn-GCaMP8f/2024_01_02/11_30_11/nwbfile/recording_merged.tif'
fr = 15

# read movie
movie_tiff = tifffile.imread(fname)

# %% [markdown]
# #### Visualize dataset and adjust `idx_row` and `idx_col`

# %%
# CHANGE ME
idx_row = [150,475] # change me
idx_col = [150,475] # change me

# plot results
plt.subplot(1,2,1)
plt.imshow(movie_tiff[1000,:,:])
plt.title("OG movie pixels")

plt.subplot(1,2,2)
plt.imshow(movie_tiff[1000,idx_row[0]:idx_row[1], idx_col[0]:idx_col[1]])
plt.title("Updated movie pixels")
# Out:
# Text(0.5, 1.0, 'Updated movie pixels')

# %%
# SAVE DATA
new_movie = movie_tiff[:,idx_row[0]:idx_row[1], idx_col[0]:idx_col[1]]
filename = fname.split('.')
print("Writing file: ",filename)
tifffile.imwrite(fname.split('.')[0]+'_mod.tif', new_movie, photometric='rgb')
# Out:
# Writing file:  ['/Users/js0403/miniscope/data/122B/AAV2/3-Syn-GCaMP8f/2024_01_02/11_30_11/nwbfile/recording_merged', 'tif']

# %%
new_movie.shape
# Out:
# (3570, 325, 325)
