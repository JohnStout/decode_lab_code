# %% [markdown]
# # Photobleach correction rationale and figures
#
# ---
#
# ### For best results, save a local copy to your machine, then upload the final versions
# -> Needs to be tested on cluster

# %%
import tifffile
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import detrend
import os
from decode_lab_code.calcium_imaging import preprocessing_utils as pu

# %% [markdown]
# # Manny Cultured recording

# %%
# name of file
fname = r'/Users/js0403/ophysdata/Manny/Manny_WSB_10-6-23_A1_20X_gfp.tif'

# load movie
movie_orig = tifffile.memmap(fname)
movie_orig.shape

if len(movie_orig.shape)>3:
    movie_orig = movie_orig[:,1,:,:]
    
# figure subplots
fig, ax = plt.subplots(nrows=1,ncols=3,figsize=(9,18))

# define vmin and max
vmin = np.min(movie_orig[0,:,:])
vmax = np.max(movie_orig[0,:,:])

# mid and end point
mid_idx = round(movie_orig.shape[0]/2)
end_idx = movie_orig.shape[0]-1

# scale data
ax[0].imshow(movie_orig[0,:,:],cmap='gray',vmin=vmin,vmax=vmax)
ax[1].imshow(movie_orig[mid_idx,:,:],cmap='gray',vmin=vmin,vmax=vmax)
ax[2].imshow(movie_orig[end_idx,:,:],cmap='gray',vmin=vmin,vmax=vmax)

# save fig
root_dir = os.path.split(fname)[0]

# example data
ex_pixel = movie_orig[:,400,400]
x = np.linspace(0,len(ex_pixel),len(ex_pixel))
y = ex_pixel

# plot data
fig2, ax2 = plt.subplots(nrows=1, ncols=2, figsize = (5, 2.5))
ax2[0].scatter(x,y, s=60, alpha=0.7, edgecolors="k")
ax2[0].set_title("Photobleaching")
ax2[0].set_ylabel("Intensity")
ax2[0].set_xlabel("Time (samples)")

# fit a linear regression line to the data
b, a = np.polyfit(x, y, deg=1)

# Plot regression line
ax2[0].plot(x, a + b * x, color="r", lw=2.5)

from scipy.signal import detrend
detrended = detrend(y, type='linear')
b, a = np.polyfit(x, detrended, deg=1)

ax2[1].scatter(x, detrended, s=60, alpha=0.7, edgecolors="k")
ax2[1].plot(x, a + b * x, color="r", lw=2.5)

ax2[1].set_title("Detrended")
ax2[1].set_xlabel("Time (samples)")
# Out:
# Text(0.5, 0, 'Time (samples)')

# %%
# name of file
fname = r'/Users/js0403/ophysdata/Manny/Manny_WSB_10-6-23_A1_20X_gfp.tif'

# load movie
movie_orig = tifffile.memmap(fname)
movie_orig.shape

if len(movie_orig.shape)>3:
    movie_orig = movie_orig[:,1,:,:]
    
# figure subplots
fig, ax = plt.subplots(nrows=1,ncols=3,figsize=(9,18))

# define vmin and max
vmin = np.min(movie_orig[0,:,:])
vmax = np.max(movie_orig[0,:,:])

# mid and end point
mid_idx = round(movie_orig.shape[0]/2)
end_idx = movie_orig.shape[0]-1

# scale data
ax[0].imshow(movie_orig[0,:,:],cmap='gray',vmin=vmin,vmax=vmax)
ax[1].imshow(movie_orig[mid_idx,:,:],cmap='gray',vmin=vmin,vmax=vmax)
ax[2].imshow(movie_orig[end_idx,:,:],cmap='gray',vmin=vmin,vmax=vmax)

# save fig
root_dir = os.path.split(fname)[0]

# example data
ex_pixel = movie_orig[:,400,400]
x = np.linspace(0,len(ex_pixel),len(ex_pixel))
y = ex_pixel

# plot data
fig2, ax2 = plt.subplots(nrows=1, ncols=2, figsize = (5, 2.5))
ax2[0].scatter(x,y, s=60, alpha=0.7, edgecolors="k")
ax2[0].set_title("Photobleaching")
ax2[0].set_ylabel("Intensity")
ax2[0].set_xlabel("Time (samples)")

# fit a linear regression line to the data
b, a = np.polyfit(x, y, deg=1)

# Plot regression line
ax2[0].plot(x, a + b * x, color="r", lw=2.5)

from scipy.signal import detrend
detrended = detrend(y, type='linear')
b, a = np.polyfit(x, detrended, deg=1)

ax2[1].scatter(x, detrended, s=60, alpha=0.7, edgecolors="k")
ax2[1].plot(x, a + b * x, color="r", lw=2.5)

ax2[1].set_title("Detrended")
ax2[1].set_xlabel("Time (samples)")
# Out:
# Text(0.5, 0, 'Time (samples)')

# %% [markdown]
# #### Load data and demonstrate photobleach effect

# %%
# define movie paths
fname = r'/Users/js0403/slice_imaging/NoSR101/_Process_45_/stack1/frame_t_0.ets - Acquisition_spatDownSampledx2.tif'

# load movie
movie_orig = tifffile.memmap(fname)
movie_orig.shape

if len(movie_orig.shape)>3:
    movie_orig = movie_orig[:,1,:,:]
    
# figure subplots
fig, ax = plt.subplots(nrows=1,ncols=3,figsize=(9,18))

# define vmin and max
vmin = np.min(movie_orig[0,:,:])
vmax = np.max(movie_orig[0,:,:])

# mid and end point
mid_idx = round(movie_orig.shape[0]/2)
end_idx = movie_orig.shape[0]-1

# scale data
ax[0].imshow(movie_orig[0,:,:],cmap='gray',vmin=vmin,vmax=vmax)
ax[1].imshow(movie_orig[mid_idx,:,:],cmap='gray',vmin=vmin,vmax=vmax)
ax[2].imshow(movie_orig[end_idx,:,:],cmap='gray',vmin=vmin,vmax=vmax)

# save fig
root_dir = os.path.split(fname)[0]

# example data
ex_pixel = movie_orig[:,400,400]
x = np.linspace(0,len(ex_pixel),len(ex_pixel))
y = ex_pixel

# plot data
fig2, ax2 = plt.subplots(nrows=1, ncols=2, figsize = (5, 2.5))
ax2[0].scatter(x,y, s=60, alpha=0.7, edgecolors="k")
ax2[0].set_title("Photobleaching")
ax2[0].set_ylabel("Intensity")
ax2[0].set_xlabel("Time (samples)")

# fit a linear regression line to the data
b, a = np.polyfit(x, y, deg=1)

# Plot regression line
ax2[0].plot(x, a + b * x, color="r", lw=2.5)

from scipy.signal import detrend
detrended = detrend(y, type='linear')
b, a = np.polyfit(x, detrended, deg=1)

ax2[1].scatter(x, detrended, s=60, alpha=0.7, edgecolors="k")
ax2[1].plot(x, a + b * x, color="r", lw=2.5)

ax2[1].set_title("Detrended")
ax2[1].set_xlabel("Time (samples)")
# Out:
# Text(0.5, 0, 'Time (samples)')

# %% [markdown]
# # Manny Ultra Parameter Search

# %%
from decode_lab_code.calcium_imaging import preprocessing_utils as preputils
import numpy as np
import matplotlib.pyplot as plt
import os
from tifffile import imread
from decode_lab_code.utils import plotter_tools as pt
# Out:
# CaImAn toolbox not loaded. Add to environment if running calcium imaging analysis

# %% [markdown]
# # Exploring some data

# %%
fname = r'/Users/js0403/Manny Movies'
dir_contents = sorted(os.listdir(fname))
print(dir_contents)
file = os.path.join(fname,dir_contents[5])
print("Reading",file)
y = imread(file)
pt.scat_data(y=y[:,0,0], x_label = "Samples", y_label = "Intensity")
# Out:
# ['A2_Test_well_nocells_movie1.tif', 'WSB_well1_A3_movie1_astrocyte_1000uL_0.tif', 'WSB_well1_A3_movie2_astrocyte_1000uL_0.tif', 'WSB_well1_A3_movie2_astrocyte_500uL_0.tif', 'WSB_well1_A3_movie4_astrocyte_1000uL_0.tif', 'WSB_well1_A3_movie5_astrocyte_1000uL_0.tif', 'WSB_well2_B3_movie10_astrocyte_1500uL_0.tif', 'WSB_well2_B3_movie1_astrocyte_1500uL_0.tif', 'WSB_well2_B3_movie2_astrocyte_1500uL_0.tif', 'WSB_well2_B3_movie3_astrocyte_1500uL_0.tif', 'WSB_well2_B3_movie4_astrocyte_1500uL_0.tif', 'WSB_well2_B3_movie5_astrocyte_1500uL_0.tif', 'WSB_well2_B3_movie6_astrocyte_1500uL_0.tif', 'WSB_well2_B3_movie7_astrocyte_1500uL_0.tif', 'WSB_well2_B3_movie8_astrocyte_1500uL_0.tif', 'WSB_well2_B3_movie9_astrocyte_1500uL_0.tif', 'c57-b6-well1_astrocyte_movie1.tif', 'c57-b6-well1_astrocyte_movie10.tif', 'c57-b6-well1_astrocyte_movie1_cmg.tif', 'c57-b6-well1_astrocyte_movie1_int.tif', 'c57-b6-well1_astrocyte_movie2.tif', 'c57-b6-well1_astrocyte_movie2_int.tif', 'c57-b6-well1_astrocyte_movie3.tif', 'c57-b6-well1_astrocyte_movie3_int.tif', 'c57-b6-well1_astrocyte_movie4.tif', 'c57-b6-well1_astrocyte_movie4_int.tif', 'c57-b6-well1_astrocyte_movie5.tif', 'c57-b6-well1_astrocyte_movie5_int.tif', 'c57-b6-well1_astrocyte_movie6.tif', 'c57-b6-well1_astrocyte_movie7.tif', 'c57-b6-well1_astrocyte_movie8.tif', 'c57-b6-well1_astrocyte_movie9.tif', 'c57-b6-well2_astrocyte_movie1_0.tif', 'c57-b6-well2_astrocyte_movie2_0.tif', 'c57-b6-well2_astrocyte_movie3_0.tif', 'c57-b6-well2_astrocyte_movie4_0.tif']
# Reading /Users/js0403/Manny Movies/WSB_well1_A3_movie5_astrocyte_1000uL_0.tif

# %% [markdown]
# I'm writing a ton of files to tif in batch. Dont rerun this

# %%
# batch_to_tif
files_path = r'/Volumes/decode/Manny/Optimizing Parameters'
image_idx = 1
downsample_factor = 4
save_path = r'/Users/js0403/Manny Movies'
dir_contents = sorted(os.listdir(files_path))
print(dir_contents)
# Out:
# ['A2_Test_well_nocells_movie1.wmv', 'WSB_well1_A3_movie1_astrocyte_1000uL_0.1M_ATP_stim.wmv', 'WSB_well1_A3_movie2_astrocyte_1000uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well1_A3_movie2_astrocyte_500uL_0.1M_ATP_stim_50int.wmv', 'WSB_well1_A3_movie4_astrocyte_1000uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well1_A3_movie5_astrocyte_1000uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well2_B3_movie10_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well2_B3_movie1_astrocyte_1500uL_0.1M_ATP_stim.wmv', 'WSB_well2_B3_movie2_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well2_B3_movie3_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well2_B3_movie4_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well2_B3_movie5_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well2_B3_movie6_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well2_B3_movie7_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well2_B3_movie8_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv', 'WSB_well2_B3_movie9_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv', 'c57-b6-well1_astrocyte_movie1.wmv', 'c57-b6-well1_astrocyte_movie10.wmv', 'c57-b6-well1_astrocyte_movie1_cmg.wmv', 'c57-b6-well1_astrocyte_movie1_int.wmv', 'c57-b6-well1_astrocyte_movie2.wmv', 'c57-b6-well1_astrocyte_movie2_int.wmv', 'c57-b6-well1_astrocyte_movie3.wmv', 'c57-b6-well1_astrocyte_movie3_int.wmv', 'c57-b6-well1_astrocyte_movie4.wmv', 'c57-b6-well1_astrocyte_movie4_int.wmv', 'c57-b6-well1_astrocyte_movie5.wmv', 'c57-b6-well1_astrocyte_movie5_int.wmv', 'c57-b6-well1_astrocyte_movie6.wmv', 'c57-b6-well1_astrocyte_movie7.wmv', 'c57-b6-well1_astrocyte_movie8.wmv', 'c57-b6-well1_astrocyte_movie9.wmv', 'c57-b6-well2_astrocyte_movie1_0.1M_ATP_stim_500uL.wmv', 'c57-b6-well2_astrocyte_movie2_0.1M_ATP_stim_500uL_notgiven.wmv', 'c57-b6-well2_astrocyte_movie3_0.1M_ATP_stim_500uL_.wmv', 'c57-b6-well2_astrocyte_movie4_0.1M_ATP_stim_500uL_.wmv']

# %%
# convert all files
preputils.batch_to_tif(files_path = files_path, image_idx = image_idx, 
                       downsample_factor = downsample_factor, 
                       save_path = save_path)
# Out:
# /Volumes/decode/Manny/Optimizing Parameters/A2_Test_well_nocells_movie1.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/A2_Test_well_nocells_movie1.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well1_A3_movie1_astrocyte_1000uL_0.1M_ATP_stim.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well1_A3_movie1_astrocyte_1000uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well1_A3_movie2_astrocyte_1000uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well1_A3_movie2_astrocyte_1000uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well1_A3_movie2_astrocyte_500uL_0.1M_ATP_stim_50int.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well1_A3_movie2_astrocyte_500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well1_A3_movie4_astrocyte_1000uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well1_A3_movie4_astrocyte_1000uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well1_A3_movie5_astrocyte_1000uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well1_A3_movie5_astrocyte_1000uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well2_B3_movie10_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well2_B3_movie10_astrocyte_1500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well2_B3_movie1_astrocyte_1500uL_0.1M_ATP_stim.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well2_B3_movie1_astrocyte_1500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well2_B3_movie2_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well2_B3_movie2_astrocyte_1500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well2_B3_movie3_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well2_B3_movie3_astrocyte_1500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well2_B3_movie4_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well2_B3_movie4_astrocyte_1500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well2_B3_movie5_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well2_B3_movie5_astrocyte_1500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well2_B3_movie6_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well2_B3_movie6_astrocyte_1500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well2_B3_movie7_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well2_B3_movie7_astrocyte_1500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well2_B3_movie8_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well2_B3_movie8_astrocyte_1500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/WSB_well2_B3_movie9_astrocyte_1500uL_0.1M_ATP_stim_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/WSB_well2_B3_movie9_astrocyte_1500uL_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie1.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie1.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie10.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie10.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie1_cmg.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie1_cmg.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie1_int.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie1_int.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie2.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie2.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie2_int.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie2_int.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie3.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie3.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie3_int.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie3_int.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie4.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie4.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie4_int.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie4_int.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie5.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie5.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie5_int.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie5_int.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie6.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie6.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie7.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie7.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie8.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie8.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well1_astrocyte_movie9.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well1_astrocyte_movie9.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well2_astrocyte_movie1_0.1M_ATP_stim_500uL.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well2_astrocyte_movie1_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well2_astrocyte_movie2_0.1M_ATP_stim_500uL_notgiven.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well2_astrocyte_movie2_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well2_astrocyte_movie3_0.1M_ATP_stim_500uL_.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well2_astrocyte_movie3_0.tif
# /Volumes/decode/Manny/Optimizing Parameters/c57-b6-well2_astrocyte_movie4_0.1M_ATP_stim_500uL_.wmv
# Please wait while data is mapped to: /Users/js0403/Manny Movies/c57-b6-well2_astrocyte_movie4_0.tif

# %%
fname = r'/Users/js0403/Manny Movies'
dir_contents = sorted(os.listdir(fname))
dir_contents
# Out:
# ['A2_Test_well_nocells_movie1.tif',
#  'WSB_well1_A3_movie1_astrocyte_1000uL_0.tif',
#  'WSB_well1_A3_movie2_astrocyte_1000uL_0.tif',
#  'WSB_well1_A3_movie2_astrocyte_500uL_0.tif',
#  'WSB_well1_A3_movie4_astrocyte_1000uL_0.tif',
#  'WSB_well1_A3_movie5_astrocyte_1000uL_0.tif',
#  'WSB_well2_B3_movie10_astrocyte_1500uL_0.tif',
#  'WSB_well2_B3_movie1_astrocyte_1500uL_0.tif',
#  'WSB_well2_B3_movie2_astrocyte_1500uL_0.tif',
#  'WSB_well2_B3_movie3_astrocyte_1500uL_0.tif',
#  'WSB_well2_B3_movie4_astrocyte_1500uL_0.tif',
#  'WSB_well2_B3_movie5_astrocyte_1500uL_0.tif',
#  'WSB_well2_B3_movie6_astrocyte_1500uL_0.tif',
#  'WSB_well2_B3_movie7_astrocyte_1500uL_0.tif',
#  'WSB_well2_B3_movie8_astrocyte_1500uL_0.tif',
#  'WSB_well2_B3_movie9_astrocyte_1500uL_0.tif',
#  'c57-b6-well1_astrocyte_movie1.tif',
#  'c57-b6-well1_astrocyte_movie10.tif',
#  'c57-b6-well1_astrocyte_movie1_cmg.tif',
#  'c57-b6-well1_astrocyte_movie1_int.tif',
#  'c57-b6-well1_astrocyte_movie2.tif',
#  'c57-b6-well1_astrocyte_movie2_int.tif',
#  'c57-b6-well1_astrocyte_movie3.tif',
#  'c57-b6-well1_astrocyte_movie3_int.tif',
#  'c57-b6-well1_astrocyte_movie4.tif',
#  'c57-b6-well1_astrocyte_movie4_int.tif',
#  'c57-b6-well1_astrocyte_movie5.tif',
#  'c57-b6-well1_astrocyte_movie5_int.tif',
#  'c57-b6-well1_astrocyte_movie6.tif',
#  'c57-b6-well1_astrocyte_movie7.tif',
#  'c57-b6-well1_astrocyte_movie8.tif',
#  'c57-b6-well1_astrocyte_movie9.tif',
#  'c57-b6-well2_astrocyte_movie1_0.tif',
#  'c57-b6-well2_astrocyte_movie2_0.tif',
#  'c57-b6-well2_astrocyte_movie3_0.tif',
#  'c57-b6-well2_astrocyte_movie4_0.tif']

# %%
fname = r'/Users/js0403/Manny Movies'
file = os.path.join(fname,dir_contents[0])
print("Reading",file)
y = imread(file)
y.shape
# Out:
# Reading /Users/js0403/Manny Movies/A2_Test_well_nocells_movie1.tif
# (1001, 498, 498)

# %%
from tifffile import imread
from scipy.stats import pearsonr
fname = r'/Users/js0403/Manny Movies'
dir_contents = sorted(os.listdir(fname))

r = []; p = []
for diri in dir_contents:
    file_read = os.path.join(fname,diri)
    y = imread(file_read)[:,0,0]
    x = np.linspace(0,len(y),len(y))

    # pearson correlation
    r_out,p_out = pearsonr(x,y)
    r.append(r_out)
    p.append(p_out)

    '''
    # fit a linear regression line to the data
    b, a = np.polyfit(x, y, deg=1)

    fig, ax = plt.subplots(nrows=1,ncols = 2)
    ax[0].imshow(imread(fname)[0,:,:])
    ax[1].scatter(x,y)
    ax[1].plot(x, a + b * x, color="r", lw=2.5)
    '''
#plt.bar(r)
# Out:
# /Users/js0403/anaconda3/envs/decode_lab_env/lib/python3.9/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
x = np.linspace(0,len(r),len(r))
y = r
plt.scatter(x, y, s=60, alpha=0.7, edgecolors="k")
plt.ylabel("Correlation Coefficient")
plt.xlabel("Movie #")
y[16]
# Out:
# 1

# %%
for i in range(len(dir_contents)):
    if i == 16:
        file_read = os.path.join(fname,diri)
        y = imread(file_read)
plt.plot(y[:,0,0])

# %%
# Out:
# Reading /Users/js0403/Manny Movies/WSB_well1_A3_movie5_astrocyte_1000uL_0.tif

# %% [markdown]
# Create a figure (x axis is movie, y-axis is correlation coefficient)

# %%
fname = r'/Users/js0403/ophysdata/Trevor_data/Neuron/750K2_200ms_4XSum_video_RedGreen_depolar002_neuron.tif'
#fname = r'/Users/js0403/ophysdata/Trevor_data/750K1_200ms_video_RedGreen003.tif'

# load movie
movie_orig = tifffile.memmap(fname)
movie_orig.shape

if len(movie_orig.shape)>3:
    movie_orig = movie_orig[:,1,:,:]
    
# figure subplots
fig, ax = plt.subplots(nrows=1,ncols=3,figsize=(9,18))

# define vmin and max
vmin = np.min(movie_orig[0,:,:])
vmax = np.max(movie_orig[0,:,:])

# mid and end point
mid_idx = round(movie_orig.shape[0]/2)
end_idx = movie_orig.shape[0]-1

# scale data
ax[0].imshow(movie_orig[0,:,:],cmap='gray',vmin=vmin,vmax=vmax)
ax[1].imshow(movie_orig[mid_idx,:,:],cmap='gray',vmin=vmin,vmax=vmax)
ax[2].imshow(movie_orig[end_idx,:,:],cmap='gray',vmin=vmin,vmax=vmax)

# save fig
root_dir = os.path.split(fname)[0]

# example data
ex_pixel = movie_orig[:,400,400]
x = np.linspace(0,len(ex_pixel),len(ex_pixel))
y = ex_pixel

# plot data
fig2, ax2 = plt.subplots(nrows=1, ncols=2, figsize = (5, 2.5))
ax2[0].scatter(x,y, s=60, alpha=0.7, edgecolors="k")
ax2[0].set_title("Photobleaching")
ax2[0].set_ylabel("Intensity")
ax2[0].set_xlabel("Time (samples)")

# fit a linear regression line to the data
b, a = np.polyfit(x, y, deg=1)

# Plot regression line
ax2[0].plot(x, a + b * x, color="r", lw=2.5)

from scipy.signal import detrend
detrended = detrend(y, type='linear')
b, a = np.polyfit(x, detrended, deg=1)

ax2[1].scatter(x, detrended, s=60, alpha=0.7, edgecolors="k")
ax2[1].plot(x, a + b * x, color="r", lw=2.5)

ax2[1].set_title("Detrended")
ax2[1].set_xlabel("Time (samples)")
# Out:
# Text(0.5, 0, 'Time (samples)')
